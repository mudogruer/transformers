# %% [markdown]
# # What if my dataset isn't on the Hub?

# %% [markdown]
# Install the Transformers, Datasets, and Evaluate libraries to run this notebook.

# %%
# !pip install datasets evaluate transformers[sentencepiece]
# Out:
# Collecting datasets
#   Downloading datasets-2.16.1-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 4.0 MB/s eta 0:00:00
# Collecting evaluate
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.4.1)
# Collecting sentencepiece!=0.1.92,>=0.1.91 (from transformers[sentencepiece])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.20.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: sentencepiece, dill, responses, multiprocess, datasets, evaluate
# Successfully installed datasets-2.16.1 dill-0.3.7 evaluate-0.4.1 multiprocess-0.70.15 responses-0.18.0 sentencepiece-0.1.99

# %%
# !wget https://github.com/crux82/squad-it/raw/master/SQuAD_it-train.json.gz
# !wget https://github.com/crux82/squad-it/raw/master/SQuAD_it-test.json.gz
# Out:
# --2024-01-09 20:39:15--  https://github.com/crux82/squad-it/raw/master/SQuAD_it-train.json.gz
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/crux82/squad-it/master/SQuAD_it-train.json.gz [following]
# --2024-01-09 20:39:15--  https://raw.githubusercontent.com/crux82/squad-it/master/SQuAD_it-train.json.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7725286 (7.4M) [application/octet-stream]
# Saving to: ‘SQuAD_it-train.json.gz’
#
# SQuAD_it-train.json 100%[===================>]   7.37M  --.-KB/s    in 0.09s
#
# 2024-01-09 20:39:15 (85.7 MB/s) - ‘SQuAD_it-train.json.gz’ saved [7725286/7725286]
#
# --2024-01-09 20:39:15--  https://github.com/crux82/squad-it/raw/master/SQuAD_it-test.json.gz
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/crux82/squad-it/master/SQuAD_it-test.json.gz [following]
# --2024-01-09 20:39:15--  https://raw.githubusercontent.com/crux82/squad-it/master/SQuAD_it-test.json.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1051245 (1.0M) [application/octet-stream]
# Saving to: ‘SQuAD_it-test.json.gz’
#
# SQuAD_it-test.json. 100%[===================>]   1.00M  --.-KB/s    in 0.05s
#
# 2024-01-09 20:39:16 (19.0 MB/s) - ‘SQuAD_it-test.json.gz’ saved [1051245/1051245]

# %%
# !gzip -dkv SQuAD_it-*.json.gz #unzip the files
# Out:
# SQuAD_it-test.json.gz:	 87.5% -- created SQuAD_it-test.json
# SQuAD_it-train.json.gz:	 82.3% -- created SQuAD_it-train.json

# %%
from datasets import load_dataset

squad_it_dataset = load_dataset("json", data_files="SQuAD_it-train.json", field="data")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
squad_it_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['paragraphs', 'title'],
#         num_rows: 442
#     })
# })

# %%
squad_it_dataset["train"][441]
# Out:
# {'paragraphs': [{'context': "Lo zinco è un elemento chimico con simbolo Zn e numero atomico 30. È il primo elemento del gruppo 12 della tavola periodica. Sotto certi aspetti lo zinco è chimicamente simile al magnesio: il suo ione è di dimensioni simili e il suo unico stato di ossidazione comune è +2. Lo zinco è il 24° elemento più abbondante nella crosta terrestre e ha cinque isotopi stabili. Il minerale di zinco più comune è la sfalerite (zinco blende), un minerale di solfuro di zinco. Le maggiori quantità estraibili si trovano in Australia, Asia e Stati Uniti. La produzione di zinco comprende la flottazione della schiuma del minerale, la tostatura e l' estrazione finale mediante energia elettrica (elettrowinning).",
#    'qas': [{'answers': [{'answer_start': 43, 'text': 'Zn'}],
#      'id': '57296e7e6aef051400154e84',
#      'question': 'Qual è il simbolo dello zinco?'},
#     {'answers': [{'answer_start': 63, 'text': '30'}],
#      'id': '57296e7e6aef051400154e85',
#      'question': 'Qual è il numero atomico per lo zinco?'},
#     {'answers': [{'answer_start': 179, 'text': 'magnesio'}],
#      'id': '57296e7e6aef051400154e86',
#      'question': 'A cosa si avvicina chimicamente lo zinco?'},
#     {'answers': [{'answer_start': 269, 'text': '+2'}],
#      'id': '57296e7e6aef051400154e87',
#      'question': 'Qual è lo stato di ossidazione dello zinco?'},
#     {'answers': [{'answer_start': 343, 'text': 'cinque'}],
#      'id': '57296e7e6aef051400154e88',
#      'question': 'Quanti isotopi stabili ha lo zinco?'},
#     {'answers': [{'answer_start': 43, 'text': 'Zn'}],
#      'id': '572b4999be1ee31400cb8301',
#      'question': 'Qual è il simbolo dello zinco?'},
#     {'answers': [{'answer_start': 63, 'text': '30'}],
#      'id': '572b4999be1ee31400cb8302',
#      'question': "Cos' è il numero atomico dello zinco?"},
#     {'answers': [{'answer_start': 179, 'text': 'magnesio'}],
#      'id': '572b4999be1ee31400cb8303',
#      'question': 'Quale altro elemento della tavola periodica è simile allo zinco?'},
#     {'answers': [{'answer_start': 404, 'text': 'sfalerite'}],
#      'id': '572b4999be1ee31400cb8304',
#      'question': 'Qual è il minerale di zinco più comune?'},
#     {'answers': [{'answer_start': 661, 'text': 'energia elettrica'}],
#      'id': '572b4999be1ee31400cb8305',
#      'question': 'Cosa viene utilizzato per estrarre lo zinco durante il processo di produzione?'}]},
#   {'context': "L' ottone, che è una lega di rame e zinco, è stato utilizzato almeno dal 10° secolo a. C. in Giudea e dal 7° secolo a. C. nell' Antica Grecia.",
#    'qas': [{'answers': [{'answer_start': 73, 'text': '10'}],
#      'id': '57296ef16aef051400154e99',
#      'question': "Quando è stato utilizzato per la prima volta l' ottone?"},
#     {'answers': [{'answer_start': 29, 'text': 'rame e zinco'}],
#      'id': '572b4ab5111d821400f38e24',
#      'question': "L' ottone è una lega di due elementi?"},
#     {'answers': [{'answer_start': 93, 'text': 'Giudea'}],
#      'id': '572b4ab5111d821400f38e25',
#      'question': "I primi usi dell' ottone sono stati attribuiti a quale antico luogo?"}]},
#   {'context': "L' elemento è stato probabilmente chiamato dall' alchimista Paracelso dopo la parola tedesca Zinke (punzone, dente). Il chimico tedesco Andreas Sigismund Marggraf ha il merito di scoprire lo zinco metallico puro nel 1746. L' opera di Luigi Galvani e Alessandro Volta ha svelato le proprietà elettrochimiche dello zinco nel 1800. La zincatura di ferro (zincatura a caldo) resistente alla corrosione è l' applicazione principale per lo zinco. Altre applicazioni sono in batterie, piccole fusioni non strutturali e leghe, come l' ottone. Una varietà di composti di zinco sono comunemente utilizzati, come carbonato di zinco e gluconato di zinco (come integratori alimentari), cloruro di zinco (nei deodoranti), pirithione di zinco (shampoo antiforforfora), solfuro di zinco (nelle pitture luminescenti), e zinco metile metilico o zinco dietile in laboratorio organico.",
#    'qas': [{'answers': [{'answer_start': 60, 'text': 'Paracelso'}],
#      'id': '57296f966aef051400154ea2',
#      'question': "Chi ha chiamato l' elemento zinco?"},
#     {'answers': [{'answer_start': 93, 'text': 'Zinke'}],
#      'id': '57296f966aef051400154ea3',
#      'question': 'Che cosa è stato chiamato zinco?'},
#     {'answers': [{'answer_start': 136, 'text': 'Andreas Sigismund Marggraf'}],
#      'id': '57296f966aef051400154ea4',
#      'question': 'Chi ha il merito di scoprire lo zinco?'},
#     {'answers': [{'answer_start': 234,
#        'text': 'Luigi Galvani e Alessandro Volta'}],
#      'id': '57296f966aef051400154ea5',
#      'question': 'Quali due persone hanno scoperto le proprietà elettrochimiche dello zinco?'},
#     {'answers': [{'answer_start': 695, 'text': 'deodoranti'}],
#      'id': '57296f966aef051400154ea6',
#      'question': 'Dove si trova il cloruro di zinco?'},
#     {'answers': [{'answer_start': 60, 'text': 'Paracelso'}],
#      'id': '572b4ba5f75d5e190021fd6a',
#      'question': 'A chi viene accreditato il nome dello zinco?'},
#     {'answers': [{'answer_start': 136, 'text': 'Andreas Sigismund Marggraf'}],
#      'id': '572b4ba5f75d5e190021fd6c',
#      'question': 'Chi ha scoperto lo zinco metallico puro?'},
#     {'answers': [{'answer_start': 351, 'text': '(zincatura a caldo'}],
#      'id': '572b4ba5f75d5e190021fd6d',
#      'question': "Qual è l' uso più comune per lo zinco?"},
#     {'answers': [{'answer_start': 695, 'text': 'deodoranti'}],
#      'id': '572b4ba5f75d5e190021fd6e',
#      'question': "Qual è l' uso comune per il cloruro di zinco?"}]},
#   {'context': 'Lo zinco è un minerale essenziale oggi percepito dal pubblico come "di eccezionale importanza per la salute pubblica e biologica", soprattutto per quanto riguarda lo sviluppo prenatale e postnatale. La carenza di zinco colpisce circa due miliardi di persone nei paesi in via di sviluppo ed è associata a molte malattie. Nei bambini provoca ritardo nella crescita, ritardi nella maturazione sessuale, suscettibilità alle infezioni e diarrea. Enzimi con un atomo di zinco nel centro reattivo sono diffusi in biochimica, come l\' alcool deidrogenasi negli esseri umani. Il consumo di zinco in eccesso può causare atassia, letargia e carenza di rame.',
#    'qas': [{'answers': [{'answer_start': 234, 'text': 'due miliardi'}],
#      'id': '5729701b1d04691400779453',
#      'question': 'Quante persone sono colpite da carenza di zinco?'},
#     {'answers': [{'answer_start': 609,
#        'text': 'atassia, letargia e carenza di rame'}],
#      'id': '5729701b1d04691400779454',
#      'question': 'Che cosa può causare il consumo di zinco in eccesso?'},
#     {'answers': [{'answer_start': 506, 'text': 'biochimica,'}],
#      'id': '5729701b1d04691400779455',
#      'question': 'Dove si trovano gli enzimi con un atomo di zinco nel centro reattivo?'},
#     {'answers': [{'answer_start': 3, 'text': 'zinco'}],
#      'id': '572b4ce0f75d5e190021fd7c',
#      'question': 'Che cosa è estremamente importante per lo sviluppo prenatale e postnatale?'},
#     {'answers': [{'answer_start': 202, 'text': 'carenza di zinco'}],
#      'id': '572b4ce0f75d5e190021fd7d',
#      'question': 'Che cosa può causare sintomi nei bambini che vanno dalla diarrea alla crescita ritardata?'},
#     {'answers': [{'answer_start': 580, 'text': 'zinco in eccesso'}],
#      'id': '572b4ce0f75d5e190021fd7f',
#      'question': 'Quali sono le cause di sintomi quali letargia e carenza di rame?'}]},
#   {'context': "Lo zinco è un metallo bianco-bluastro, brillante, diamagnetico, anche se la maggior parte dei comuni gradi commerciali del metallo hanno una finitura opaca. È un po' meno denso del ferro e ha una struttura cristallina esagonale, con una forma distorta di chiusura esagonale, in cui ogni atomo ha sei vicini più vicini (a 265,9 pm) nel proprio piano e altri sei ad una distanza maggiore di 290,6 pm. Il metallo è duro e fragile alla maggior parte delle temperature, ma diventa malleabile tra 100 e 150 °C. Al di sopra dei 210 °C, il metallo diventa nuovamente fragile e può essere polverizzato battendo. Lo zinco è un conduttore equo di elettricità. Per un metallo, lo zinco ha una fusione relativamente bassa (419,5 °C) e punti di ebollizione (907 °C). Il suo punto di fusione è il più basso di tutti i metalli di transizione, ad eccezione del mercurio e del cadmio.",
#    'qas': [{'answers': [{'answer_start': 22, 'text': 'bianco-bluastro'}],
#      'id': '572970803f37b319004783c5',
#      'question': 'Che colore è zinco?'},
#     {'answers': [{'answer_start': 157,
#        'text': "È un po' meno denso del ferro"}],
#      'id': '572970803f37b319004783c6',
#      'question': 'Il ferro è più denso dello zinco?'},
#     {'answers': [{'answer_start': 491, 'text': '100 e 150 °C'}],
#      'id': '572970803f37b319004783c7',
#      'question': 'A quale temperatura il metallo diventa malleabile?'},
#     {'answers': [{'answer_start': 521, 'text': '210 °C'}],
#      'id': '572970803f37b319004783c8',
#      'question': 'A quale temperatura di zinco diventa fragile?'},
#     {'answers': [{'answer_start': 744, 'text': '907 °C'}],
#      'id': '572970803f37b319004783c9',
#      'question': 'Qual è il punto di ebollizione dello zinco?'},
#     {'answers': [{'answer_start': 22, 'text': 'bianco-bluastro'}],
#      'id': '572b4db9111d821400f38e3e',
#      'question': 'Nel suo stato pre commerciale, che colore è zinco?'},
#     {'answers': [{'answer_start': 218, 'text': 'esagonale'}],
#      'id': '572b4db9111d821400f38e3f',
#      'question': 'Qual è la struttura cristallina della sincronizzazione?'},
#     {'answers': [{'answer_start': 468, 'text': 'diventa malleabile'}],
#      'id': '572b4db9111d821400f38e40',
#      'question': 'Cosa succede allo zinco quando viene manipolato alle temperature comprese tra 100 e 150 gradi Celsius?'},
#     {'answers': [{'answer_start': 521, 'text': '210 °C'}],
#      'id': '572b4db9111d821400f38e41',
#      'question': 'A quale temperatura può essere polverizzato lo zinco?'}]},
#   {'context': "Diverse decine di radioisotopi sono stati caratterizzati. 65Zn, che ha un tempo di dimezzamento di 243,66 giorni, è il radioisotopo più longevo, seguito da 72Zn con un tempo di dimezzamento di 46,5 ore. Lo zinco ha 10 isomeri nucleari. 69mZn ha il tempo di dimezzamento più lungo, 13,76 h. L' apice m indica un isotopo metastabile. Il nucleo di un isotopo metastabile è in uno stato eccitato e tornerà allo stato di terra emettendo un fotone sotto forma di raggio gamma. 61Zn ha tre stati eccitati e 73Zn ne ha due. Gli isotopi 65Zn, 71Zn, 77Zn e 78Zn hanno ciascuno uno stato eccitato.",
#    'qas': [{'answers': [{'answer_start': 311, 'text': 'isotopo metastabile'}],
#      'id': '5729710a6aef051400154ed0',
#      'question': "Cosa rappresenta l' apice m?"},
#     {'answers': [{'answer_start': 479, 'text': 'tre'}],
#      'id': '5729710a6aef051400154ed1',
#      'question': 'Quanti Stati eccitati ha 61Zn?'},
#     {'answers': [{'answer_start': 511, 'text': 'due'}],
#      'id': '5729710a6aef051400154ed2',
#      'question': 'Quanti Stati eccitati ha 73Zn?'},
#     {'answers': [{'answer_start': 58, 'text': '65Zn'}],
#      'id': '572b5109111d821400f38e5a',
#      'question': "Qual è l' isotopo radio più longevo?"},
#     {'answers': [{'answer_start': 193, 'text': '46,5 ore'}],
#      'id': '572b5109111d821400f38e5b',
#      'question': "Che cos' è la mezza vita di 72Zn?"},
#     {'answers': [{'answer_start': 215, 'text': '10'}],
#      'id': '572b5109111d821400f38e5c',
#      'question': 'Quanti isomeri nucleari ha lo zinco?'},
#     {'answers': [{'answer_start': 311, 'text': 'isotopo metastabile'}],
#      'id': '572b5109111d821400f38e5d',
#      'question': 'Cosa indica l\' apice "m"?'}]},
#   {'context': 'The chemistry of zinc is dominated by the +2 oxidation state. When compounds in this oxidation state are formed the outer shell s electrons are lost, which yields a bare zinc ion with the electronic configuration [Ar]3d10. In aqueous solution an octahedral complex, [Zn(H\n2O)6]2+ is the predominant species. The volatilization of zinc in combination with zinc chloride at temperatures above 285 °C indicates the formation of Zn\n2Cl\n2, a zinc compound with a +1 oxidation state. No compounds of zinc in oxidation states other than +1 or +2 are known. Calculations indicate that a zinc compound with the oxidation state of +4 is unlikely to exist.',
#    'qas': [{'answers': [{'answer_start': 42, 'text': '+2'}],
#      'id': '5729717d6aef051400154ed8',
#      'question': 'What oxidation state dominates zinc?'},
#     {'answers': [{'answer_start': 308,
#        'text': 'The volatilization of zinc in combination with zinc chloride at temperatures above 285 °C'}],
#      'id': '5729717d6aef051400154ed9',
#      'question': 'What indicates the formation of ZN2Cl?'},
#     {'answers': [{'answer_start': 530, 'text': '+1 or +2'}],
#      'id': '5729717d6aef051400154eda',
#      'question': 'what are the only two oxidation states known for zinc?'},
#     {'answers': [{'answer_start': 42, 'text': '+2'}],
#      'id': '572b520df75d5e190021fd84',
#      'question': 'What oxidation state dominates the chemistry of zinc?'},
#     {'answers': [{'answer_start': 530, 'text': '+1 or +2'}],
#      'id': '572b520df75d5e190021fd87',
#      'question': 'What are the only two oxidation states known for zinc compounds?'}]},
#   {'context': "La chimica dello zinco è simile a quella dei metalli nichel e rame di transizione di prima fila tardiva, anche se ha un guscio d-riempito, quindi i suoi composti sono diamagnetici e per lo più incolore. I raggi ionici di zinco e magnesio sono quasi identici. A causa di questo alcuni dei loro sali hanno la stessa struttura cristallina e in circostanze dove il raggio ionico è un fattore determinante la chimica dello zinco e del magnesio hanno molto in comune. Altrimenti c' è poca somiglianza. Lo zinco tende a formare legami con un maggior grado di covalenza e forma complessi molto più stabili con i donatori N e S-. I complessi di zinco sono per lo più a 4 o 6 coordinate, anche se sono noti complessi a 5 coordinate.",
#    'qas': [{'answers': [{'answer_start': 361, 'text': 'raggio ionico'}],
#      'id': '572b5334111d821400f38e65',
#      'question': 'Qual è il fattore determinante quando zinco e magnesio sono molto simili chimicamente?'},
#     {'answers': [{'answer_start': 613, 'text': 'N e S-'}],
#      'id': '572b5334111d821400f38e66',
#      'question': 'Con quali donatori lo zinco forma complessi stabili?'}]},
#   {'context': 'I composti di zinco (I) sono rari e richiedono leganti ingombranti per stabilizzare lo stato di bassa ossidazione. La maggior parte dei composti di zinco (I) contiene formalmente il nucleo[Zn2]2+, che è analogo al catione dimerica[Hg2]2+ presente nei composti di mercurio (I). La natura diamagnetica dello ione conferma la sua struttura dimerica. Il primo composto di zinco (I) contenente il legame Zn-Zn, (? 5-C5Me5)2Zn2, è anche il primo dimetallocene. Lo ione[Zn2]2+ si sproporziona rapidamente in zinco metallo e zinco (II) ed è stato ottenuto solo come vetro giallo formato raffreddando una soluzione di zinco metallico in ZnCl2 fuso.',
#    'qas': [{'answers': [{'answer_start': 47, 'text': 'leganti ingombranti'}],
#      'id': '572b5405be1ee31400cb832b',
#      'question': 'Cosa è necessario per stabilizzare il basso stato di ossidazione dei composti di zinco (l)?'},
#     {'answers': [{'answer_start': 189, 'text': 'Zn2]2+'}],
#      'id': '572b5405be1ee31400cb832c',
#      'question': 'Quale nucleo contiene la maggior parte dei composti di zinco (l)?'},
#     {'answers': [{'answer_start': 280,
#        'text': 'natura diamagnetica dello ione'}],
#      'id': '572b5405be1ee31400cb832d',
#      'question': 'Cosa conferma la struttura dimerica del composto?'},
#     {'answers': [{'answer_start': 558, 'text': 'vetro giallo'}],
#      'id': '572b5405be1ee31400cb832e',
#      'question': 'Quando una soluzione di zinco metallico viene raffreddata in ZnCl2 fuso, che cosa si forma?'}]},
#   {'context': 'Binary compounds of zinc are known for most of the metalloids and all the nonmetals except the noble gases. The oxide ZnO is a white powder that is nearly insoluble in neutral aqueous solutions, but is amphoteric, dissolving in both strong basic and acidic solutions. The other chalcogenides (ZnS, ZnSe, and ZnTe) have varied applications in electronics and optics. Pnictogenides (Zn\n3N\n2, Zn\n3P\n2, Zn\n3As\n2 and Zn\n3Sb\n2), the peroxide (ZnO\n2), the hydride (ZnH\n2), and the carbide (ZnC\n2) are also known. Of the four halides, ZnF\n2 has the most ionic character, whereas the others (ZnCl\n2, ZnBr\n2, and ZnI\n2) have relatively low melting points and are considered to have more covalent character.',
#    'qas': [{'answers': [{'answer_start': 95, 'text': 'noble gases'}],
#      'id': '572b550a34ae481900dead8f',
#      'question': 'What is not known for binary compounds of zinc?'},
#     {'answers': [{'answer_start': 233,
#        'text': 'strong basic and acidic solutions'}],
#      'id': '572b550a34ae481900dead90',
#      'question': 'ZnO can be dissolved in what kind of solutions?'},
#     {'answers': [{'answer_start': 342, 'text': 'electronics and optics.'}],
#      'id': '572b550a34ae481900dead91',
#      'question': 'What applications do chalcogenides have?'}]},
#   {'context': 'In weak basic solutions containing Zn2+ ions, the hydroxide Zn(OH)\n2 forms as a white precipitate. In stronger alkaline solutions, this hydroxide is dissolved to form zincates ([Zn(OH)4]2−). The nitrate Zn(NO3)\n2, chlorate Zn(ClO3)\n2, sulfate ZnSO\n4, phosphate Zn\n3(PO4)\n2, molybdate ZnMoO\n4, cyanide Zn(CN)\n2, arsenite Zn(AsO2)\n2, arsenate Zn(AsO4)\n2·8H\n2O and the chromate ZnCrO\n4 (one of the few colored zinc compounds) are a few examples of other common inorganic compounds of zinc. One of the simplest examples of an organic compound of zinc is the acetate (Zn(O\n2CCH3)\n2).',
#    'qas': [{'answers': [{'answer_start': 167, 'text': 'zincates'}],
#      'id': '572b55d7be1ee31400cb8334',
#      'question': 'Zn(OH)2 is dissolved to form what in strong alkaline solutions?'}]},
#   {'context': "Il Charaka Samhita, che si pensa sia stato scritto tra il 300 e il 500 d. C., cita un metallo che, una volta ossidato, produce pushpanjan, ritenuto ossido di zinco. Le miniere di zinco di Zawar, vicino a Udaipur in India, sono attive dal periodo mauryan. La fusione di zinco metallico qui, tuttavia, sembra essere iniziata intorno al XII secolo dC. Si stima che questo sito abbia prodotto un milione di tonnellate di zinco metallico e ossido di zinco dal XII al XVI secolo. Un' altra stima fornisce una produzione totale di 60 000 tonnellate di zinco metallico in questo periodo.",
#    'qas': [{'answers': [{'answer_start': 238, 'text': 'periodo mauryan'}],
#      'id': '572b56cd34ae481900dead9a',
#      'question': 'Le miniere di zinco attive in India risalgono a quale periodo?'},
#     {'answers': [{'answer_start': 258, 'text': 'fusione di zinco metallico'}],
#      'id': '572b56cd34ae481900dead9b',
#      'question': 'Qual è stato il processo nel XII secolo?'}]},
#   {'context': 'Il nome del metallo fu probabilmente documentato per la prima volta da Paracelso, alchimista tedesco di origine svizzera, che nel suo libro Liber Mineralium II, nel XVI secolo, definì il metallo "zinco" o "zinken". La parola deriva probabilmente dal zinke tedesco e significa presumibilmente "a denti, appuntiti o frastagliati" (i cristalli di zinco metallizzato hanno un aspetto simile ad un ago). Zink potrebbe anche implicare "stagno-come" a causa della sua relazione con zinn tedesco che significa stagno. Un\' altra possibilità è che la parola derivi dalla parola persiana? seng che significa pietra? Il metallo era anche chiamato stagno indiano, tutanego, calamina e spinter. Paracelso.',
#    'qas': [{'answers': [{'answer_start': 635,
#        'text': 'stagno indiano, tutanego, calamina e spinter'}],
#      'id': '572b581a34ae481900deadaa',
#      'question': 'Quali sono alcuni degli altri termini per lo zinco?'}]},
#   {'context': 'Il fratello di William Champion, John, brevettò nel 1758 un processo per la calcinazione del solfuro di zinco in un ossido utilizzabile nel processo di storta. In precedenza, solo la calamina poteva essere utilizzata per produrre zinco. Nel 1798, Johann Christian Ruberg migliorò il processo di fusione costruendo la prima fonderia di storta orizzontale. Jean-Jacques Daniel Dony costruì in Belgio un altro tipo di fonderia orizzontale di zinco, che trasformava ancora più zinco. Il medico italiano Luigi Galvani scoprì nel 1780 che il collegamento del midollo spinale di una rana appena sezionata ad un binario di ferro fissato da un gancio in ottone portò la gamba della rana a twitch. Ha erroneamente pensato che aveva scoperto una capacità di nervi e muscoli di creare elettricità e chiamato l\' effetto "elettricità animale". La cella galvanica e il processo di galvanizzazione sono stati entrambi chiamati per Luigi Galvani e queste scoperte hanno spianato la strada a batterie elettriche, galvanizzazione e protezione catodica.',
#    'qas': [{'answers': [{'answer_start': 183, 'text': 'calamina'}],
#      'id': '572b5939f75d5e190021fd93',
#      'question': "Prima di John Champion, qual era l' unico elemento utilizzato per produrre zinco?"},
#     {'answers': [{'answer_start': 247, 'text': 'Johann Christian Ruberg'}],
#      'id': '572b5939f75d5e190021fd94',
#      'question': 'Chi ha costruito la prima fonderia di storta orizzontale?'},
#     {'answers': [{'answer_start': 808, 'text': 'elettricità animale'}],
#      'id': '572b5939f75d5e190021fd95',
#      'question': "Che cosa ha fatto Galvani chiamare l' effetto che ha creato facendo twitchare le gambe delle rane?"},
#     {'answers': [{'answer_start': 974,
#        'text': 'batterie elettriche, galvanizzazione e protezione catodica'}],
#      'id': '572b5939f75d5e190021fd96',
#      'question': 'Le scoperte fatte da Galvani portano a tre cose importanti?'}]},
#   {'context': 'Zinc metal is produced using extractive metallurgy. After grinding the ore, froth flotation, which selectively separates minerals from gangue by taking advantage of differences in their hydrophobicity, is used to get an ore concentrate. This concentrate consists of about 50% zinc with the rest being sulfur (32%), iron (13%), and SiO\n2 (5%). The composition of this is normally zinc sulfide (80% to 85%), iron sulfide (7.0% to 12%), lead sulfide (3.0% to 5.0%) silica (2.5% to 3.5%), and cadmium sulfide (0.35% to 0.41%).',
#    'qas': [{'answers': [{'answer_start': 29,
#        'text': 'extractive metallurgy.'}],
#      'id': '572b5a02111d821400f38e72',
#      'question': 'What is used to produce the metal zinc?'},
#     {'answers': [{'answer_start': 213, 'text': 'get an ore concentrate'}],
#      'id': '572b5a02111d821400f38e73',
#      'question': 'What is froth flotation used for?'},
#     {'answers': [{'answer_start': 58, 'text': 'grinding the ore'}],
#      'id': '572b5a02111d821400f38e74',
#      'question': 'What is the first step in zinc metal production?'},
#     {'answers': [{'answer_start': 272, 'text': '50%'}],
#      'id': '572b5a02111d821400f38e75',
#      'question': 'What percentage of the ore concentrate is zinc?'}]},
#   {'context': "La produzione di minerali solfidici di zinco produce grandi quantità di anidride solforosa e vapori di cadmio. Anche le scorie di fonderia e altri residui del processo contengono quantità significative di metalli pesanti. Tra il 1806 e il 1882, nelle città belghe di La Calamine e Plombières, tra il 1806 e il 1882 sono stati estratti e fusi circa 1,1 milioni di tonnellate di zinco metallico e 130 mila tonnellate di piombo. Le discariche delle precedenti operazioni minerarie lisciviavano quantità significative di zinco e cadmio e, di conseguenza, i sedimenti del fiume Geul contengono quantità significative di metalli pesanti. Circa duemila anni fa le emissioni di zinco provenienti dall' estrazione e dalla fusione erano pari a 10 mila tonnellate all' anno. Dopo essere aumentate di 10 volte rispetto al 1850, le emissioni di zinco hanno raggiunto un picco di 3,4 milioni di tonnellate all' anno negli anni' 80 e sono scese a 2,7 milioni di tonnellate negli anni' 90, anche se uno studio condotto nel 2005 sulla troposfera artica ha rilevato che le concentrazioni non riflettevano il declino. Le emissioni antropogeniche e naturali si verificano in un rapporto di 20 a 1.",
#    'qas': [{'answers': [{'answer_start': 0,
#        'text': 'La produzione di minerali solfidici di zinco'}],
#      'id': '572b5afd34ae481900deadbd',
#      'question': 'A causa di che cosa si producono grandi quantità di anidride solforosa e vapori di cadmio?'},
#     {'answers': [{'answer_start': 205, 'text': 'metalli pesanti'}],
#      'id': '572b5afd34ae481900deadbe',
#      'question': 'Le scorie di fonderia contengono una quantità significativa di ciò che?'}]},
#   {'context': 'Zinc is more reactive than iron or steel and thus will attract almost all local oxidation until it completely corrodes away. A protective surface layer of oxide and carbonate (Zn\n5(OH)\n6(CO\n3)\n2) forms as the zinc corrodes. This protection lasts even after the zinc layer is scratched but degrades through time as the zinc corrodes away. The zinc is applied electrochemically or as molten zinc by hot-dip galvanizing or spraying. Galvanization is used on chain-link fencing, guard rails, suspension bridges, lightposts, metal roofs, heat exchangers, and car bodies.',
#    'qas': [{'answers': [{'answer_start': 27, 'text': 'iron or steel'}],
#      'id': '572b5bab34ae481900deadc5',
#      'question': 'What two compounds is zinc more reactive than?'},
#     {'answers': [{'answer_start': 127,
#        'text': 'protective surface layer of oxide and carbonate'}],
#      'id': '572b5bab34ae481900deadc6',
#      'question': 'What forms as zinc corrodes?'},
#     {'answers': [{'answer_start': 358,
#        'text': 'electrochemically or as molten zinc'}],
#      'id': '572b5bab34ae481900deadc7',
#      'question': 'How is zinc applied?'},
#     {'answers': [{'answer_start': 430, 'text': 'Galvanization'}],
#      'id': '572b5bab34ae481900deadc8',
#      'question': 'What is used on many common items, such as chain link fences?'}]},
#   {'context': "La relativa reattività dello zinco e la sua capacità di attrarre l' ossidazione ne fa un anodo sacrificale efficiente nella protezione catodica (CP). Ad esempio, la protezione catodica di una tubazione interrata può essere ottenuta collegando gli anodi di zinco al tubo. Lo zinco funge da anodo (terminale negativo) e si corrode lentamente passando corrente elettrica alla tubazione d' acciaio. Lo zinco è usato anche per proteggere dalla corrosione i metalli esposti all' acqua di mare. Un disco di zinco attaccato al timone di ferro della nave si corrode lentamente, mentre il timone rimane staccato.",
#    'qas': [{'answers': [{'answer_start': 124, 'text': 'protezione catodica'}],
#      'id': '572b5c93111d821400f38e7b',
#      'question': 'Collegamento anodi di collegamento in zinco al tubo interrato crea cosa?'},
#     {'answers': [{'answer_start': 422,
#        'text': "proteggere dalla corrosione i metalli esposti all' acqua di mare"}],
#      'id': '572b5c93111d821400f38e7c',
#      'question': 'Che cosa fa il fissaggio di un disco di zinco a un timone di ferro di una nave?'},
#     {'answers': [{'answer_start': 546,
#        'text': 'si corrode lentamente, mentre il timone rimane staccato'}],
#      'id': '572b5c93111d821400f38e7d',
#      'question': "Perché lo zinco protegge i metalli esposti all' acqua di mare dalla corrosione?"}]},
#   {'context': "Altre leghe largamente usate che contengono zinco includono l' argento nichel, metallo della macchina da scrivere, saldatura morbida e alluminio e bronzo commerciale. Lo zinco è utilizzato anche negli organi di tubazioni contemporanei come sostituto della tradizionale lega piombo/tagno nei tubi. Leghe di zinco 85-88%, rame 4-10% e alluminio 28% trovano un uso limitato in alcuni tipi di cuscinetti per macchine. Lo zinco è il metallo primario utilizzato nella produzione di monete americane da un centesimo dal 1982. L' anima in zinco è rivestita con un sottile strato di rame per dare l' impressione di una moneta in rame. Nel 1994,33.200 tonnellate (36.600 tonnellate corte) di zinco sono state utilizzate per produrre 13,6 miliardi di centesimi negli Stati Uniti.",
#    'qas': []},
#   {'context': "Le leghe di zinco principalmente con piccole quantità di rame, alluminio e magnesio sono utili sia nella pressofusione che nella centrifuga, specialmente nell' industria automobilistica, elettrica e della ferramenta. Queste leghe sono commercializzate con il nome di Zamak. Un esempio di questo è l' alluminio zinco. Il basso punto di fusione e la bassa viscosità della lega rendono possibile la produzione di forme piccole e complesse. La bassa temperatura di esercizio porta ad un rapido raffreddamento dei prodotti fusi ed è quindi possibile un montaggio rapido. Un' altra lega, commercializzata con il marchio Prestal, contiene il 78% di zinco e il 22% di alluminio ed è considerata forte quasi quanto l' acciaio, ma malleabile come la plastica. Questa superplasticità della lega permette di stamparla utilizzando pressofusioni in ceramica e cemento.",
#    'qas': [{'answers': [{'answer_start': 267, 'text': 'Zama'}],
#      'id': '572b7b86be1ee31400cb83dc',
#      'question': 'Le leghe di zinco miscelate con rame, alluminio e magnesio sono commercializzate come cosa?'},
#     {'answers': [{'answer_start': 410, 'text': 'forme piccole e complesse'}],
#      'id': '572b7b86be1ee31400cb83dd',
#      'question': 'Che cosa è possibile produrre grazie al basso punto di fusione e alla bassa viscosità della lega di zinco-alluminio?'},
#     {'answers': [{'answer_start': 614, 'text': 'Prestal'}],
#      'id': '572b7b86be1ee31400cb83de',
#      'question': "Quale marchio di lega dovrebbe essere forte come l' acciaio e allo stesso tempo malleabile come la plastica?"}]},
#   {'context': "Leghe simili con l' aggiunta di una piccola quantità di piombo possono essere laminate a freddo in fogli. Una lega del 96% di zinco e del 4% di alluminio viene utilizzata per la realizzazione di stampi di stampaggio per applicazioni a bassa produzione per le quali gli stampi di metallo ferroso sarebbero troppo costosi. Nelle facciate di edifici, tetti o altre applicazioni in cui lo zinco viene utilizzato come lamiera e per metodi quali imbutitura, formatura a rullo o piegatura, vengono utilizzate leghe di zinco con titanio e rame. Lo zinco non legato è troppo fragile per questi tipi di processi di fabbricazione.",
#    'qas': [{'answers': [{'answer_start': 195, 'text': 'stampi di stampaggio'}],
#      'id': '572b7c55be1ee31400cb83e6',
#      'question': "Cos' è realizzato con una lega di alluminio al 4% di alluminio miscelato con zinco al 96%?"},
#     {'answers': [{'answer_start': 559, 'text': 'troppo fragile'}],
#      'id': '572b7c55be1ee31400cb83e8',
#      'question': 'Perché non viene utilizzato zinco non legato nelle applicazioni edili?'}]},
#   {'context': "Circa un quarto di tutta la produzione di zinco negli Stati Uniti (2009) è consumata sotto forma di composti di zinco, una varietà dei quali viene utilizzata industrialmente. L' ossido di zinco è ampiamente utilizzato come pigmento bianco nelle vernici e come catalizzatore nella fabbricazione della gomma. Viene anche utilizzato anche come disperdente di calore per la gomma e agisce per proteggere i suoi polimeri dalle radiazioni ultraviolette (la stessa protezione UV è conferita alle materie plastiche contenenti ossido di zinco). Le proprietà semiconduttori dell' ossido di zinco lo rendono utile nei varistori e nei prodotti di fotocopiatura. Il ciclo zinco-ossido di zinco-zinco è un processo termochimico in due fasi a base di zinco e ossido di zinco per la produzione di idrogeno.",
#    'qas': [{'answers': [{'answer_start': 100, 'text': 'composti di zinco'}],
#      'id': '572b7d1b111d821400f38eb0',
#      'question': 'In quale forma viene utilizzato 1/4 di zinco negli Stati Uniti?'},
#     {'answers': [{'answer_start': 178, 'text': 'ossido di zinco'}],
#      'id': '572b7d1b111d821400f38eb1',
#      'question': 'Che tipo di composto di zinco viene utilizzato nella fabbricazione della gomma?'},
#     {'answers': [{'answer_start': 178, 'text': 'ossido di zinco'}],
#      'id': '572b7d1b111d821400f38eb2',
#      'question': 'Cosa protegge i polimeri in gomma dai raggi ultravioletti?'},
#     {'answers': [{'answer_start': 701, 'text': 'termochimico'}],
#      'id': '572b7d1b111d821400f38eb4',
#      'question': 'Che tipo di processo è il ciclo zinco-ossido di zinco-ossido?'}]},
#   {'context': 'Zinc chloride is often added to lumber as a fire retardant and can be used as a wood preservative. It is also used to make other chemicals. Zinc methyl (Zn(CH3)\n2) is used in a number of organic syntheses. Zinc sulfide (ZnS) is used in luminescent pigments such as on the hands of clocks, X-ray and television screens, and luminous paints. Crystals of ZnS are used in lasers that operate in the mid-infrared part of the spectrum. Zinc sulfate is a chemical in dyes and pigments. Zinc pyrithione is used in antifouling paints.',
#    'qas': [{'answers': [{'answer_start': 0, 'text': 'Zinc chloride'}],
#      'id': '572b7df5f75d5e190021fe0a',
#      'question': 'What is added to wood in order to preserve it?'},
#     {'answers': [{'answer_start': 236, 'text': 'luminescent pigments'}],
#      'id': '572b7df5f75d5e190021fe0b',
#      'question': 'What is the feature of zinc sufide that makes it useful in television screens?'},
#     {'answers': [{'answer_start': 395, 'text': 'mid-infrared'}],
#      'id': '572b7df5f75d5e190021fe0c',
#      'question': 'What kind of lasers are crystals of zinc suflde used in?'},
#     {'answers': [{'answer_start': 506, 'text': 'antifouling paints.'}],
#      'id': '572b7df5f75d5e190021fe0d',
#      'question': 'Where is zinc pyrithion used?'}]},
#   {'context': "64Zn, l' isotopo più abbondante di zinco, è molto sensibile all' attivazione del neutrone, essendo trasmutato nel altamente radioattivo 65Zn, che ha un tempo di dimezzamento di 244 giorni e produce radiazioni gamma intense. Per questo motivo, l' ossido di zinco utilizzato nei reattori nucleari come agente anticorrosivo è esaurito di 64 Zn prima dell' uso, questo è chiamato ossido di zinco impoverito. Per lo stesso motivo, lo zinco è stato proposto come materiale salante per le armi nucleari (il cobalto è un altro materiale salino più noto). Una giacca di 64Zn arricchita isotopicamente sarebbe irradiata dall' intenso flusso di neutroni ad alta energia proveniente da un' arma termonucleare esplosiva, formando una grande quantità di 65Zn aumentando significativamente la radioattività della caduta dell' arma. Non è noto che tale arma sia mai stata costruita, testata o utilizzata. 65Zn è anche usato come tracciante per studiare come le leghe che contengono zinco si consumano, o il percorso e il ruolo dello zinco negli organismi.",
#    'qas': [{'answers': [{'answer_start': 0, 'text': '64Zn'}],
#      'id': '572b7eb8be1ee31400cb83ed',
#      'question': "Qual è l' isotopo di zinco più abbondante?"},
#     {'answers': [{'answer_start': 307, 'text': 'anticorrosivo'}],
#      'id': '572b7eb8be1ee31400cb83ef',
#      'question': "Perché l' ossido di zinco viene utilizzato nei reattori nucleari?"},
#     {'answers': [{'answer_start': 136, 'text': '65Zn'}],
#      'id': '572b7eb8be1ee31400cb83f0',
#      'question': 'Che cosa viene usato per studiare come le leghe contenenti zinco si consumano?'}]},
#   {'context': "Lo zinco è incluso nella maggior parte dei supplementi minerali e vitaminici giornalieri della maggior parte delle compresse da banco. I preparati comprendono ossido di zinco, acetato di zinco e gluconato di zinco. Si ritiene di possedere proprietà antiossidanti, che possono proteggere contro l' invecchiamento accelerato della pelle e dei muscoli del corpo; gli studi differiscono per la sua efficacia. Lo zinco aiuta anche ad accelerare il processo di guarigione dopo un infortunio. E' anche sospettato di essere benefico per il sistema immunitario del corpo. Infatti, la carenza di zinco può avere effetti su praticamente tutte le parti del sistema immunitario umano.",
#    'qas': []},
#   {'context': "Anche se non ancora testato come terapia negli esseri umani, un corpo crescente di prove indica che lo zinco può uccidere preferibilmente cellule tumorali della prostata. Poiché lo zinco alloggia naturalmente nella prostata e poiché la prostata è accessibile con procedure relativamente non invasive, il suo potenziale come agente chemioterapico in questo tipo di cancro ha dimostrato di essere promettente. Tuttavia, altri studi hanno dimostrato che l' uso cronico di integratori di zinco in eccesso rispetto al dosaggio raccomandato può effettivamente aumentare la possibilità di sviluppare il cancro alla prostata, probabilmente anche a causa dell' accumulo naturale di questo metallo pesante nella prostata.",
#    'qas': [{'answers': [{'answer_start': 161, 'text': 'prostata'}],
#      'id': '572b80e034ae481900deae4d',
#      'question': 'Che tipo di cellule cancerogene possono uccidere lo zinco?'},
#     {'answers': [{'answer_start': 331, 'text': 'chemioterapico'}],
#      'id': '572b80e034ae481900deae4e',
#      'question': 'Che tipo di agente è utile contro il cancro della prostata?'},
#     {'answers': [{'answer_start': 596, 'text': 'cancro alla prostata'}],
#      'id': '572b80e034ae481900deae4f',
#      'question': 'Che cosa potrebbe causare un uso eccessivo di zinco?'}]},
#   {'context': "Ci sono molti importanti composti organozinc. La chimica organozinc è la scienza dei composti organozinc che ne descrive le proprietà fisiche, la sintesi e le reazioni. Tra le applicazioni più importanti c' è la reazione Frankland-Duppa Reaction in cui un estere ossalato (ROCOCOOR) reagisce con un alogenuro di alchile R' X, zinco e acido cloridrico agli esteri -idrossicarbossilici RR' COHCOOR, la reazione di Reformatskii che converte -aloroesteri e aldeidi in -idrossi-dosatori, i Simmons? La reazione di Barbier (1899) è l' equivalente zinco della reazione di magnesio Grignard ed è migliore delle due. In presenza di quasi tutta l' acqua la formazione dell' alogenuro di organomagnesio fallirà, mentre la reazione di Barbier può avvenire anche in acqua. Sul lato negativo gli organozincs sono molto meno nucleofili rispetto ai Grignards, sono costosi e difficili da maneggiare. I composti diorganozinc disponibili in commercio sono: dimetilzinco, dietilzinco e difenilzinco. In uno studio, il composto attivo di organozinc è ottenuto da precursori di organobromina molto più economici: proprietà fisiche, sintesi e reazioni. La reazione di Barbier.",
#    'qas': [{'answers': [{'answer_start': 886,
#        'text': 'composti diorganozinc disponibili in commercio'}],
#      'id': '572b81bc34ae481900deae56',
#      'question': 'Che cosa sono il dimetilzinco, il dietilcinc e il difenilzinco?'}]},
#   {'context': "Lo zinco svolge un ruolo puramente strutturale nelle dita di zinco, torsioni e grappoli. Le dita di zinco formano parti di alcuni fattori di trascrizione, che sono proteine che riconoscono le sequenze di base del DNA durante la replicazione e la trascrizione del DNA. Ciascuno dei nove o dieci ioni Zn2+ in un dito di zinco aiuta a mantenere la struttura del dito, legandosi in modo coordinato a quattro aminoacidi nel fattore di trascrizione. Il fattore di trascrizione si avvolge intorno all' elica del DNA e utilizza le dita per legarsi accuratamente alla sequenza del DNA.",
#    'qas': [{'answers': [{'answer_start': 35, 'text': 'strutturale'}],
#      'id': '572b8267111d821400f38eba',
#      'question': 'Che ruolo ha lo zinco nelle dita, nelle torsioni e nei grappoli?'},
#     {'answers': [{'answer_start': 130, 'text': 'fattori di trascrizione,'}],
#      'id': '572b8267111d821400f38ebb',
#      'question': 'Cosa sono le proteine che druing replicazione e trascrizione di DNA, riconoscere DNA di base?'},
#     {'answers': [{'answer_start': 396, 'text': 'quattro'}],
#      'id': '572b8267111d821400f38ebc',
#      'question': 'Quanti aminoacidi si legano agli ioni Zn2+?'}]},
#   {'context': "Altre fonti includono alimenti arricchiti e integratori alimentari, che sono disponibili in varie forme. Un riesame del 1998 ha concluso che l' ossido di zinco, uno degli integratori più comuni negli Stati Uniti, e il carbonato di zinco sono quasi insolubili e scarsamente assorbiti nell' organismo. Questa revisione ha citato studi che hanno rilevato basse concentrazioni di zinco plasmatico dopo il consumo di ossido di zinco e carbonato di zinco rispetto a quelli osservati dopo il consumo di acetato di zinco e sali di solfato di zinco. Tuttavia, l' integrazione eccessiva dannosa è un problema tra i relativamente ricchi, e probabilmente non dovrebbe superare i 20 mg / die in persone sane, anche se il Consiglio Nazionale delle Ricerche degli Stati Uniti d' America ha fissato una dose tollerabile superiore di 40 mg / die. ossido di zinco.",
#    'qas': []},
#   {'context': "Per la fortificazione, tuttavia, una revisione del 2003 raccomandava di utilizzare l' ossido di zinco nei cereali a basso costo, stabile e facilmente assorbibile come forme più costose. Uno studio del 2005 ha rilevato che vari composti di zinco, compresi ossido e solfato, non mostravano differenze statisticamente significative nell' assorbimento se aggiunti come fortificanti alle tortillas del granturco. Uno studio del 1987 ha dimostrato che il picolinato di zinco è stato assorbito meglio del gluconato di zinco o del citrato di zinco. Tuttavia, uno studio pubblicato nel 2008 ha stabilito che il glicinato di zinco è il migliore assorbito dei quattro tipi di integratori alimentari disponibili.",
#    'qas': [{'answers': [{'answer_start': 106, 'text': 'cereali'}],
#      'id': '572b83d2111d821400f38ec2',
#      'question': "L' ossido di zinco viene utilizzato per fortificare quale prodotto?"},
#     {'answers': [{'answer_start': 449, 'text': 'picolinato di zinco'}],
#      'id': '572b83d2111d821400f38ec4',
#      'question': 'Quale composto è meglio assorbito del gluconato di zinco?'},
#     {'answers': [{'answer_start': 602, 'text': 'glicinato di zinco'}],
#      'id': '572b83d2111d821400f38ec5',
#      'question': 'Qual è il composto di zinco più assorbito nella dieta?'}]},
#   {'context': "I sintomi di una lieve carenza di zinco sono diversi. I risultati clinici includono crescita depressa, diarrea, impotenza e maturazione sessuale ritardata, alopecia, lesioni oculari e cutanee, appetito indebolito, alterazione della cognizione, compromissione delle proprietà di difesa dell' ospite, difetti nell' utilizzo dei carboidrati e teratogenesi riproduttiva. La leggera carenza di zinco deprime l' immunità, anche se lo zinco eccessivo fa anche. Gli animali con una dieta carente di zinco richiedono il doppio di cibo per raggiungere lo stesso aumento di peso degli animali con sufficiente zinco.",
#    'qas': [{'answers': [{'answer_start': 17,
#        'text': 'lieve carenza di zinco'}],
#      'id': '572b84ba34ae481900deae5d',
#      'question': 'I sintomi che vanno dalla diarrea alle lesioni oculari sono da che cosa?'}]},
#   {'context': "Nonostante alcune preoccupazioni, vegetariani e vegani occidentali non sono stati trovati a soffrire di evidenti carenze di zinco più che mangiatori di carne. Le principali fonti vegetali di zinco includono fagioli secchi cotti, ortaggi di mare, cereali fortificati, soia, noci, piselli e semi. Tuttavia, i fittati in molti cereali integrali e fibre in molti alimenti possono interferire con l' assorbimento dello zinco e l' assunzione di zinco marginale ha effetti poco compresi. Il fitato chelatore di zinco, presente nelle sementi e nella crusca di cereali, può contribuire al malassorbimento dello zinco. Ci sono alcune prove per suggerire che più di quanto la RDA degli Stati Uniti (15 mg) di zinco al giorno può essere necessario in quelli la cui dieta è ad alto contenuto di fittati, come alcuni vegetariani. Queste considerazioni devono essere ponderate rispetto al fatto che vi è una scarsità di biomarcatori dello zinco adeguati e che l' indicatore più utilizzato, lo zinco plasmatico, ha scarsa sensibilità e specificità. La diagnosi della carenza di zinco è una sfida persistente.",
#    'qas': [{'answers': [{'answer_start': 173, 'text': 'fonti vegetali'}],
#      'id': '572b85aef75d5e190021fe20',
#      'question': 'Qual è il modo in cui vegetariani e vegani ottengono lo zinco?'}]},
#   {'context': "Quasi due miliardi di persone nei paesi in via di sviluppo sono carenti di zinco. Nei bambini provoca un aumento dell' infezione e della diarrea, contribuendo alla morte di circa 800.000 bambini in tutto il mondo ogni anno. L' Organizzazione Mondiale della Sanità sostiene l' integrazione di zinco per malnutrizione grave e diarrea. Integratori di zinco aiutano a prevenire le malattie e ridurre la mortalità, soprattutto tra i bambini con basso peso alla nascita o la crescita stentata. Tuttavia, gli integratori di zinco non dovrebbero essere somministrati da soli, perché molti nei paesi in via di sviluppo hanno diverse carenze, e lo zinco interagisce con altri micronutrienti.",
#    'qas': [{'answers': [{'answer_start': 75, 'text': 'zinc'}],
#      'id': '572b8667111d821400f38ed2',
#      'question': '800.000 bambini in tutto il mondo muoiono ogni anno a causa di che cosa?'},
#     {'answers': [{'answer_start': 276, 'text': 'integrazione di zinco'}],
#      'id': '572b8667111d821400f38ed3',
#      'question': "Cosa raccomanda l' OMS per la malnutrizione e la diarrea?"}]},
#   {'context': "La carenza di zinco è la più comune carenza di micronutrienti nelle piante coltivate; è particolarmente comune nei terreni ad alto contenuto di zinco. Il suolo povero di zinco è coltivato nel terreno coltivabile di circa la metà della Turchia e dell' India, un terzo della Cina, e la maggior parte dell' Australia occidentale, e in queste zone sono state segnalate risposte sostanziali alla fecondazione dello zinco. Le piante che crescono in suoli poveri di zinco sono più sensibili alle malattie. Lo zinco è principalmente aggiunto al suolo attraverso gli agenti atmosferici delle rocce, ma gli esseri umani hanno aggiunto zinco attraverso la combustione di combustibili fossili, rifiuti minerari, fertilizzanti fosfatici, pesticidi (fosfuro di zinco), calcare, letame, fanghi di depurazione e particelle da superfici zincate. Lo zinco in eccesso è tossico per le piante, anche se la tossicità dello zinco è molto meno diffusa.",
#    'qas': []},
#   {'context': 'C\' è evidenza di carenza di rame indotto in coloro che prendono 100-300 mg di zinco al giorno. Uno studio del 2007 ha osservato che gli uomini anziani che assumono 80 mg al giorno sono stati ricoverati in ospedale per complicazioni urinarie più spesso di quelli che prendono un placebo. L\' USDA RDA è 11 e 8 mg Zn al giorno per uomini e donne, rispettivamente. Livelli di 100-300 mg possono interferire con l\' utilizzo di rame e ferro o influenzare negativamente il colesterolo. Livelli di zinco superiori a 500 ppm nel terreno interferiscono con la capacità delle piante di assorbire altri metalli essenziali, come ferro e manganese. C\' è anche una condizione chiamata "brividi di zinco", che può essere indotta dall\' inalazione di ossido di zinco appena formatosi durante la saldatura di materiali zincati. Lo zinco è un ingrediente comune della crema protesica che può contenere tra 17 e 38 mg di zinco per grammo. Ci sono state denunce di invalidità, e anche morte, a causa dell\' uso eccessivo di questi prodotti.',
#    'qas': [{'answers': [{'answer_start': 28, 'text': 'rame'}],
#      'id': '572b8803be1ee31400cb8405',
#      'question': 'Che tipo di carenza è comune dal prendere 100-300mg di zinco al giorno?'}]},
#   {'context': "La Food and Drug Administration (FDA) degli Stati Uniti ha dichiarato che lo zinco danneggia i recettori nervosi nel naso, che possono causare anosmia. Rapporti di anosmia sono stati osservati anche nel 1930 quando i preparati di zinco sono stati utilizzati in un tentativo fallito per prevenire le infezioni da poliomielite. Il 16 giugno 2009, la FDA ha detto che i consumatori dovrebbero smettere di utilizzare prodotti a base di zinco a base di freddo intranasale e ha ordinato la loro rimozione dagli scaffali del negozio. La FDA ha detto che la perdita di odore può essere pericolosa per la vita, perché le persone con cattivo odore non è in grado di rilevare perdite di gas o fumo e non può dire se il cibo ha rovinato prima di mangiarlo. Recenti ricerche suggeriscono che il pirithione di zinco antimicrobico topico è un potente induttore di risposta agli shock termici che può compromettere l' integrità genomica con l' induzione di crisi energetica PARP-dipendente in cheratinociti umani colti e melanociti. recettori nervosi.",
#    'qas': [{'answers': [{'answer_start': 782,
#        'text': 'pirithione di zinco antimicrobico'}],
#      'id': '572b88b934ae481900deae7d',
#      'question': 'Quale prodotto suggerisce come potente induttore di risposta agli shock termici?'}]},
#   {'context': "Nel 1982, la Zecca degli Stati Uniti iniziò a coniare penny rivestiti in rame ma fatti principalmente di zinco. Con i nuovi centesimi di zinco, c' è il potenziale di tossicità dello zinco, che può essere fatale. Un caso segnalato di ingestione cronica di 425 penny (oltre 1 kg di zinco) ha causato la morte per sepsi batterica gastrointestinale e fungina, mentre un altro paziente, che ha ingerito 12 grammi di zinco, ha mostrato solo letargia e atassia (la lorda mancanza di coordinamento dei movimenti muscolari). Diversi altri casi sono stati segnalati di esseri umani che soffrono di intossicazione da zinco per ingestione di monete di zinco.",
#    'qas': [{'answers': [{'answer_start': 124, 'text': 'centesimi'}],
#      'id': '572b8993f75d5e190021fe42',
#      'question': 'A partire dal 1982, quale moneta è ora costituita principalmente da zinco?'},
#     {'answers': [{'answer_start': 446, 'text': 'atassia'}],
#      'id': '572b8993f75d5e190021fe44',
#      'question': "L' ingestione di zinco può causare la mancanza di movimento muscolare e coordinamento chiamato quello che?"}]},
#   {'context': "Pennies e altre monete piccole a volte sono ingerite dai cani, con conseguente necessità di cure mediche per rimuovere il corpo estraneo. Il contenuto di zinco di alcune monete può causare la tossicità dello zinco, che è comunemente mortale nei cani, dove provoca una grave anemia emolitica, e anche danni al fegato o ai reni; vomito e diarrea sono sintomi possibili. Lo zinco è altamente tossico nei pappagalli e l' avvelenamento può spesso essere mortale. Il consumo di succhi di frutta conservati in lattine zincate ha portato ad avvelenamenti di pappagallo massa con zinco.",
#    'qas': [{'answers': [{'answer_start': 0, 'text': 'Pennies'}],
#      'id': '572b8a60be1ee31400cb8423',
#      'question': 'Che cosa sono i cani che si sa ingerire?'},
#     {'answers': [{'answer_start': 192, 'text': 'tossicità dello zinco'}],
#      'id': '572b8a60be1ee31400cb8424',
#      'question': 'Che cosa causano le monete di zinco ingerite dai cani?'},
#     {'answers': [{'answer_start': 401, 'text': 'pappagalli'}],
#      'id': '572b8a60be1ee31400cb8425',
#      'question': 'In quale animale lo zinco è tossico fino al punto di velenosi?'}]}],
#  'title': 'Zinco'}

# %%
data_files = {"train": "SQuAD_it-train.json", "test": "SQuAD_it-test.json"}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
squad_it_dataset
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['paragraphs', 'title'],
#         num_rows: 442
#     })
#     test: Dataset({
#         features: ['paragraphs', 'title'],
#         num_rows: 48
#     })
# })

# %%
data_files = {"train": "SQuAD_it-train.json.gz", "test": "SQuAD_it-test.json.gz"}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
url = "https://github.com/crux82/squad-it/raw/master/"
data_files = {
    "train": url + "SQuAD_it-train.json.gz",
    "test": url + "SQuAD_it-test.json.gz",
}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
# Out:
# Downloading data:   0%|          | 0.00/7.73M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.05M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
squad_it_dataset["test"][0]
# Out:
# {'paragraphs': [{'context': 'La crisi petrolifera del 1973 iniziò nell\' ottobre 1973 quando i membri dell\' Organizzazione dei Paesi esportatori di petrolio arabo (OAPEC, composta dai membri arabi dell\' OPEC più Egitto e Siria) proclamarono un embargo petrolifero. Alla fine dell\' embargo, nel marzo 1974, il prezzo del petrolio era salito da 3 dollari al barile a quasi 12 dollari a livello mondiale; i prezzi americani erano notevolmente più elevati. L\' embargo ha causato una crisi petrolifera, o "shock", con molti effetti a breve e lungo termine sulla politica globale e sull\' economia globale. Più tardi fu chiamato il "primo shock petrolifero", seguito dalla crisi petrolifera del 1979, definita il "secondo shock petrolifero".',
#    'qas': [{'answers': [{'answer_start': 43, 'text': 'ottobre 1973'},
#       {'answer_start': 43, 'text': 'ottobre 1973'},
#       {'answer_start': 43, 'text': 'ottobre 1973'},
#       {'answer_start': 43, 'text': 'ottobre'},
#       {'answer_start': 25, 'text': '1973'}],
#      'id': '5725b33f6a3fe71400b8952d',
#      'question': 'Quando è iniziata la crisi petrolifera del 1973?'},
#     {'answers': [{'answer_start': 658, 'text': '1979'},
#       {'answer_start': 658, 'text': '1979'},
#       {'answer_start': 658, 'text': '1979'},
#       {'answer_start': 658, 'text': '1979'},
#       {'answer_start': 658, 'text': '1979'}],
#      'id': '5725b33f6a3fe71400b8952f',
#      'question': 'Quando è stata la seconda crisi petrolifera?'},
#     {'answers': [{'answer_start': 471, 'text': 'shock'},
#       {'answer_start': 471, 'text': 'shock'},
#       {'answer_start': 471, 'text': 'shock'}],
#      'id': '5725b33f6a3fe71400b89530',
#      'question': 'Qual è stato un altro termine utilizzato per la crisi petrolifera?'},
#     {'answers': [{'answer_start': 65,
#        'text': "membri dell' Organizzazione dei Paesi esportatori di petrolio arabo"},
#       {'answer_start': 65,
#        'text': "membri dell' Organizzazione dei Paesi esportatori di petrolio arabo"},
#       {'answer_start': 78,
#        'text': 'Organizzazione dei Paesi esportatori di petrolio arabo'},
#       {'answer_start': 65,
#        'text': "membri dell' Organizzazione dei Paesi esportatori di petrolio arabo"},
#       {'answer_start': 134, 'text': 'OAPEC'}],
#      'id': '5725b33f6a3fe71400b89531',
#      'question': "Chi ha proclamato l' embargo petrolifero?"}]},
#   {'context': "La crisi ha avuto un forte impatto sulle relazioni internazionali e ha creato una frattura all' interno della NATO. Alcune nazioni europee e il Giappone hanno cercato di dissociarsi dalla politica estera degli Stati Uniti in Medio Oriente per evitare di essere presi di mira dal boicottaggio. I produttori arabi di petrolio hanno collegato eventuali cambiamenti politici futuri alla pace tra i belligeranti. Per affrontare questo problema, l' amministrazione Nixon ha avviato negoziati multilaterali con i combattenti. Hanno fatto in modo che Israele tornasse dalla penisola del Sinai e dalle alture del Golan. A partire dal 18 gennaio 1974, il segretario di Stato statunitense Henry Kissinger aveva negoziato il ritiro di una truppa israeliana da alcune parti della penisola del Sinai. La promessa di un accordo negoziato tra Israele e Siria è stata sufficiente per convincere i produttori di petrolio arabo a revocare l' embargo nel marzo 1974.",
#    'qas': [{'answers': [{'answer_start': 243,
#        'text': 'evitare di essere presi di mira dal boicottaggio'},
#       {'answer_start': 243,
#        'text': 'evitare di essere presi di mira dal boicottaggio'},
#       {'answer_start': 243,
#        'text': 'evitare di essere presi di mira dal boicottaggio'},
#       {'answer_start': 243,
#        'text': 'evitare di essere presi di mira dal boicottaggio'},
#       {'answer_start': 243,
#        'text': 'evitare di essere presi di mira dal boicottaggio'}],
#      'id': '5725b5a689a1e219009abd28',
#      'question': 'Perchè le nazioni europee e il Giappone si sono separati dagli Stati Uniti durante la crisi?'},
#     {'answers': [{'answer_start': 625, 'text': '18 gennaio 1974'},
#       {'answer_start': 625, 'text': '18 gennaio 1974'},
#       {'answer_start': 625, 'text': '18 gennaio 1974,'}],
#      'id': '5725b5a689a1e219009abd29',
#      'question': 'In quale data Henry Kissinger ha negoziato un ritiro di truppe israeliane dalla penisola del Sinai?'},
#     {'answers': [{'answer_start': 935, 'text': 'marzo 1974'},
#       {'answer_start': 935, 'text': 'marzo 1974'},
#       {'answer_start': 935, 'text': 'marzo 1974'},
#       {'answer_start': 935, 'text': 'marzo 1974'},
#       {'answer_start': 935, 'text': 'marzo 1974'}],
#      'id': '5725b5a689a1e219009abd2a',
#      'question': "Quando hanno revocato l' embargo i produttori di petrolio arabi?"}]},
#   {'context': 'Il 15 agosto 1971, gli Stati Uniti uscirono unilateralmente dall\' accordo di Bretton Woods. Gli Stati Uniti hanno abbandonato l\' Gold Exchange Standard, in base al quale il valore del dollaro era stato ancorato al prezzo dell\' oro e tutte le altre valute erano ancorate al dollaro, il cui valore era lasciato "fluttuare" (aumento e diminuzione a seconda della domanda del mercato). Poco dopo, seguì la Gran Bretagna, facendo fluttuare la lira sterlina. Gli altri paesi industrializzati seguirono l\' esempio con le rispettive valute. Anticipando che i valori valutari fluttuassero in modo imprevedibile per un certo periodo di tempo, i paesi industrializzati hanno aumentato le loro riserve (ampliando le loro scorte di moneta) in quantità molto maggiori di prima. Il risultato è stato un deprezzamento del dollaro e delle valute di altri paesi industrializzati. Poichè il prezzo del petrolio era in dollari, il reddito reale dei produttori di petrolio è diminuito. Nel settembre 1971, l\' OPEC ha pubblicato un comunicato congiunto nel quale dichiarava che, da quel momento in poi, il prezzo del petrolio sarebbe stato fissato a un importo fisso di oro.',
#    'qas': [{'answers': [{'answer_start': 0, 'text': 'Il 15 agosto 1971'},
#       {'answer_start': 3, 'text': '15 agosto 1971'},
#       {'answer_start': 3, 'text': '15 agosto 1971'},
#       {'answer_start': 3, 'text': '15 agosto 1971'},
#       {'answer_start': 3, 'text': '15 agosto 1971'}],
#      'id': '5725b76389a1e219009abd4a',
#      'question': "Quando si sono ritirati gli Stati Uniti dall' accordo di Bretton Woods?"},
#     {'answers': [{'answer_start': 633,
#        'text': 'i paesi industrializzati hanno aumentato le loro riserve'}],
#      'id': '5725b76389a1e219009abd4c',
#      'question': "Perchè c' è stato un deprezzamento dei dollari delle nazioni industrializzate?"},
#     {'answers': [{'answer_start': 965, 'text': 'Nel settembre 1971'},
#       {'answer_start': 969, 'text': 'settembre 1971'},
#       {'answer_start': 969, 'text': 'settembre 1971'},
#       {'answer_start': 969, 'text': 'settembre 1971'},
#       {'answer_start': 969, 'text': 'settembre 1971'}],
#      'id': '5725b76389a1e219009abd4d',
#      'question': "Quando l' olio ha cominciato ad ottenere prezzi in termini di oro?"}]},
#   {'context': 'Questo ha contribuito alla "scossa da olio". Dopo il 1971, l\' OPEC ha tardato ad adeguare i prezzi per riflettere tale deprezzamento. Dal 1947 al 1967, il prezzo del petrolio in dollari è aumentato di meno del 2% all\' anno. Fino allo shock petrolifero, il prezzo era rimasto abbastanza stabile anche nei confronti di altre valute e materie prime. I ministri dell\' OPEC non avevano sviluppato meccanismi istituzionali per aggiornare i prezzi in sintonia con le mutevoli condizioni di mercato, per cui i loro redditi reali sono rimasti indietro. I sostanziali aumenti di prezzo del 1973-1974 hanno ampiamente riportato i loro prezzi e i corrispondenti redditi ai livelli di Bretton Woods in termini di materie prime come l\' oro.',
#    'qas': [{'answers': [{'answer_start': 186,
#        'text': "è aumentato di meno del 2% all' anno"},
#       {'answer_start': 201, 'text': "meno del 2% all' anno"},
#       {'answer_start': 201, 'text': "meno del 2% all' anno"},
#       {'answer_start': 198, 'text': "di meno del 2% all' anno"},
#       {'answer_start': 201, 'text': "meno del 2% all' anno"}],
#      'id': '5725b92e38643c19005acbd3',
#      'question': 'Dal 1947 al 1967, quanto è aumentato il prezzo del petrolio?'},
#     {'answers': [{'answer_start': 45, 'text': 'Dopo il 1971'},
#       {'answer_start': 53, 'text': '1971'},
#       {'answer_start': 45, 'text': 'Dopo il 1971'},
#       {'answer_start': 53, 'text': '1971'}],
#      'id': '5725b92e38643c19005acbd4',
#      'question': "Quando ha iniziato l' OPEC a riadattare i prezzi del petrolio?"},
#     {'answers': [{'answer_start': 585, 'text': '1974'}],
#      'id': '5725b92e38643c19005acbd5',
#      'question': "Quando l' olio è tornato ai suoi livelli di Bretton Woods?"}]},
#   {'context': 'Il 6 ottobre 1973, la Siria e l\' Egitto, con il sostegno di altre nazioni arabe, lanciarono un attacco a sorpresa su Israele, su Yom Kippur. Questo rinnovo delle ostilità nel conflitto arabo-israeliano ha liberato la pressione economica sottostante sui prezzi del petrolio. All\' epoca, l\' Iran era il secondo esportatore mondiale di petrolio e un vicino alleato degli Stati Uniti. Settimane più tardi, lo scià d\' Iran ha detto in un\' intervista:"Naturalmente[il prezzo del petrolio] sta andando a salire Certamente! E come! Avete[Paesi occidentali] aumentato il prezzo del grano che ci vendete del 300 per cento, e lo stesso per zucchero e cemento. Voi comprate il nostro petrolio greggio e rivendete a noi, raffinato come petrolchimico, a cento volte il prezzo che ci avete pagato E\' giusto che d\' ora in poi si paghi di più per il petrolio. Diciamo dieci volte di più". Il 6 ottobre 1973.',
#    'qas': [{'answers': [{'answer_start': 3, 'text': '6 ottobre 1973'},
#       {'answer_start': 3, 'text': '6 ottobre 1973'},
#       {'answer_start': 3, 'text': '6 ottobre 1973'},
#       {'answer_start': 3, 'text': '6 ottobre 1973'}],
#      'id': '5725bad5271a42140099d0bd',
#      'question': "Quando la Siria e l' Egitto hanno lanciato un attacco a sorpresa contro Israele?"},
#     {'answers': [{'answer_start': 851, 'text': 'dieci volte di più'},
#       {'answer_start': 851, 'text': 'dieci'},
#       {'answer_start': 289, 'text': 'Iran'},
#       {'answer_start': 851, 'text': 'dieci'}],
#      'id': '5725bad5271a42140099d0be',
#      'question': "Quante volte di più le altre nazioni hanno dovuto pagare per il petrolio dopo l' attacco a sorpresa?"},
#     {'answers': [{'answer_start': 139, 'text': '.'}],
#      'id': '5725bad5271a42140099d0bf',
#      'question': "Perchè lo scià d' Iran ha rilasciato un' intervista?"}]},
#   {'context': 'In risposta agli aiuti americani a Israele, il 16 ottobre 1973, l\' OPEC ha aumentato il prezzo del petrolio del 70%, portandolo a 5,11 dollari al barile. Il giorno successivo, i ministri del petrolio hanno approvato l\' embargo, con una riduzione della produzione del cinque per cento rispetto alla produzione di settembre e hanno deciso di continuare a ridurre la produzione con incrementi mensili del cinque per cento fino al raggiungimento dei loro obiettivi economici e politici. Il 19 ottobre Nixon ha chiesto al Congresso di stanziare 2,2 miliardi di dollari in aiuti d\' emergenza a Israele, inclusi 1,5 miliardi di dollari in sovvenzioni a fondo perduto. George Lenczowski osserva:"Le forniture militari non esauriscono la volontà di Nixon di impedire il crollo di Israele Questa decisione[$2,2 miliardi] ha scatenato una risposta collettiva dell\' OPEC". La Libia ha immediatamente annunciato che avrebbe embargo sulle spedizioni di petrolio verso gli Stati Uniti. L\' Arabia Saudita e gli altri Stati arabi produttori di petrolio hanno aderito all\' embargo il 20 ottobre 1973. In occasione della riunione del Kuwait, l\' OAPEC ha proclamato l\' embargo che limitava le esportazioni verso vari paesi e bloccava tutte le consegne di petrolio negli Stati Uniti come "principale paese ostile".',
#    'qas': [{'answers': [{'answer_start': 0,
#        'text': 'In risposta agli aiuti americani a Israele'},
#       {'answer_start': 0,
#        'text': 'In risposta agli aiuti americani a Israele'},
#       {'answer_start': 0,
#        'text': 'In risposta agli aiuti americani a Israele'},
#       {'answer_start': 0,
#        'text': 'In risposta agli aiuti americani a Israele'}],
#      'id': '5725bcb6271a42140099d0eb',
#      'question': "Perchè l' OPEC ha portato il prezzo del petrolio a 5,11 dollari?"},
#     {'answers': [{'answer_start': 47, 'text': '16 ottobre 1973,'},
#       {'answer_start': 47, 'text': '16 ottobre 1973'},
#       {'answer_start': 47, 'text': '16 ottobre 1973'},
#       {'answer_start': 47, 'text': '16 ottobre 1973'},
#       {'answer_start': 47, 'text': '16 ottobre 1973'}],
#      'id': '5725bcb6271a42140099d0ec',
#      'question': 'Quando hanno portato il prezzo del petrolio a 5,11 dollari?'},
#     {'answers': [{'answer_start': 419,
#        'text': 'fino al raggiungimento dei loro obiettivi economici e politici'},
#       {'answer_start': 0,
#        'text': 'In risposta agli aiuti americani a Israele'},
#       {'answer_start': 64,
#        'text': "l' OPEC ha aumentato il prezzo del petrolio"},
#       {'answer_start': 419,
#        'text': 'fino al raggiungimento dei loro obiettivi economici e politici'}],
#      'id': '5725bcb6271a42140099d0ed',
#      'question': 'Perchè i ministri del petrolio hanno accettato di tagliare la produzione petrolifera?'},
#     {'answers': [{'answer_start': 796, 'text': '$2,2 miliardi'},
#       {'answer_start': 796, 'text': '$2,2 miliardi'},
#       {'answer_start': 796, 'text': '$2,2 miliardi'},
#       {'answer_start': 796, 'text': '$2,2 miliardi'},
#       {'answer_start': 796, 'text': '$2,2 miliardi'}],
#      'id': '5725bcb6271a42140099d0ee',
#      'question': "A quanto ammontavano gli aiuti d' urgenza a Israele?"},
#     {'answers': [{'answer_start': 497,
#        'text': "Nixon ha chiesto al Congresso di stanziare 2,2 miliardi di dollari in aiuti d' emergenza a Israele"},
#       {'answer_start': 1123,
#        'text': 'l\' OAPEC ha proclamato l\' embargo che limitava le esportazioni verso vari paesi e bloccava tutte le consegne di petrolio negli Stati Uniti come "principale paese ostile"'},
#       {'answer_start': 1123,
#        'text': "l' OAPEC ha proclamato l' embargo che limitava le esportazioni verso vari paesi"}],
#      'id': '5725bcb6271a42140099d0ef',
#      'question': "Perchè l' OPEC ha bloccato le consegne di petrolio negli Stati Uniti?"}]},
#   {'context': "Una parte del reddito è stata erogata sotto forma di aiuti ad altri paesi sottosviluppati le cui economie erano state catturate tra l' aumento dei prezzi del petrolio e la diminuzione dei prezzi delle materie prime destinate all' esportazione, in un contesto di contrazione della domanda occidentale. Molto è andato per gli acquisti di armi che hanno esacerbato le tensioni politiche, soprattutto in Medio Oriente. L' Arabia Saudita ha speso oltre 100 miliardi di dollari nei decenni successivi per contribuire a diffondere la sua interpretazione fondamentalista dell' Islam, noto come Wahhabismo, in tutto il mondo, attraverso organizzazioni di beneficenza religiose come la Fondazione al-Haramain, che spesso ha distribuito fondi anche a violenti gruppi estremisti sunniti come Al-Qaeda e i Talebani.",
#    'qas': [{'answers': [{'answer_start': 442,
#        'text': 'oltre 100 miliardi di dollari'},
#       {'answer_start': 442, 'text': 'oltre 100 miliardi di dollari'},
#       {'answer_start': 442, 'text': 'oltre 100 miliardi di dollari'},
#       {'answer_start': 442, 'text': 'oltre 100 miliardi di dollari'},
#       {'answer_start': 448, 'text': '100 miliardi di dollari'}],
#      'id': '57261dab38643c19005ad037',
#      'question': "Quanto ha speso l' Arabia Saudita per diffondere il wahhabismo?"},
#     {'answers': [{'answer_start': 780, 'text': 'Al-Qaeda e i Talebani'},
#       {'answer_start': 740,
#        'text': 'violenti gruppi estremisti sunniti come Al-Qaeda e i Talebani'},
#       {'answer_start': 780, 'text': 'Al-Qaeda e i Talebani'},
#       {'answer_start': 780, 'text': 'Al-Qaeda e i Talebani'},
#       {'answer_start': 780, 'text': 'Al-Qaeda e i Talebani'}],
#      'id': '57261dab38643c19005ad038',
#      'question': "Quale gruppo ha beneficiato dei fondi distribuiti dalla fondazione al-Haramain, l' associazione religiosa al-Haramain Foundation?"},
#     {'answers': [{'answer_start': 400, 'text': 'Medio Oriente'},
#       {'answer_start': 400, 'text': 'Medio Oriente'},
#       {'answer_start': 400, 'text': 'Medio Oriente'},
#       {'answer_start': 400, 'text': 'Medio Oriente'},
#       {'answer_start': 400, 'text': 'Medio Oriente'}],
#      'id': '57261dab38643c19005ad039',
#      'question': "Una parte delle entrate è stata destinata all' acquisto di armi che hanno esacerbato le tensioni politiche, soprattutto in quale area?"},
#     {'answers': [{'answer_start': 262,
#        'text': 'contrazione della domanda occidentale'},
#       {'answer_start': 262, 'text': 'contrazione della domanda occidentale'},
#       {'answer_start': 262, 'text': 'contrazione della domanda occidentale'}],
#      'id': '57261dab38643c19005ad03a',
#      'question': 'Qual è una delle ragioni per cui i paesi sottosviluppati hanno ricevuto aiuti dal reddito petrolifero?'},
#     {'answers': [{'answer_start': 586, 'text': 'Wahhabismo'},
#       {'answer_start': 586, 'text': 'Wahhabismo'},
#       {'answer_start': 586, 'text': 'Wahhabismo'},
#       {'answer_start': 586, 'text': 'Wahhabismo'},
#       {'answer_start': 586, 'text': 'Wahhabismo'}],
#      'id': '57261dab38643c19005ad03b',
#      'question': "Che cos' è una interpretazione fondamentalista dell' Islam chiamata?"}]},
#   {'context': 'Negli Stati Uniti, gli studiosi sostengono che esisteva già un accordo negoziato basato sull\' uguaglianza tra le due parti prima del 1973. La possibilità che il Medio Oriente potesse diventare un altro confronto di superpotenza con l\' URSS era più preoccupante per gli Stati Uniti che per il petrolio. Inoltre, i gruppi d\' interesse e le agenzie governative più preoccupati per l\' energia non erano all\' altezza della dominanza di Kissinger. Negli Stati Uniti la produzione, la distribuzione e le perturbazioni dei prezzi "sono state ritenute responsabili di recessioni, periodi di eccessiva inflazione, riduzione della produttività e minore crescita economica".',
#    'qas': [{'answers': [{'answer_start': 133, 'text': '1973'},
#       {'answer_start': 133, 'text': '1973'},
#       {'answer_start': 133, 'text': '1973'},
#       {'answer_start': 133, 'text': '1973'}],
#      'id': '57261f9f271a42140099d4ab',
#      'question': 'Gli studiosi hanno dichiarato che esisteva già un accordo esistente tra due parti prima di tale data?'},
#     {'answers': [{'answer_start': 431, 'text': 'Kissinger'},
#       {'answer_start': 431, 'text': 'Kissinger'},
#       {'answer_start': 431, 'text': 'Kissinger'},
#       {'answer_start': 431, 'text': 'Kissinger'}],
#      'id': '57261f9f271a42140099d4ac',
#      'question': "I gruppi d' interesse e le agenzie governative che si occupavano di energia non erano all' altezza di chi?"}]},
#   {'context': "L' embargo ha avuto un' influenza negativa sull' economia statunitense, causando richieste immediate di affrontare le minacce alla sicurezza energetica degli Stati Uniti. A livello internazionale, gli aumenti di prezzo hanno cambiato le posizioni competitive in molti settori, come quello automobilistico. I problemi macroeconomici hanno avuto un impatto sia inflazionistico che deflazionistico. L' embargo ha lasciato le compagnie petrolifere alla ricerca di nuovi modi per aumentare le forniture di petrolio, anche in terreni difficili come l' Artico. L' individuazione del petrolio e lo sviluppo di nuovi giacimenti richiedeva in genere da cinque a dieci anni prima di una produzione significativa. L' embargo.",
#    'qas': [{'answers': [{'answer_start': 0, 'text': "L' embargo"},
#       {'answer_start': 0, 'text': "L' embargo"},
#       {'answer_start': 0, 'text': "L' embargo"},
#       {'answer_start': 3, 'text': 'embargo'}],
#      'id': '5726241189a1e219009ac2de',
#      'question': "Che cosa influisce negativamente sull' economia statunitense?"},
#     {'answers': [{'answer_start': 308, 'text': 'problemi macroeconomici'}],
#      'id': '5726241189a1e219009ac2df',
#      'question': "Quale problema consiste sia nell' impatto inflazionistico che deflazionistico?"},
#     {'answers': [{'answer_start': 546, 'text': 'Artico'},
#       {'answer_start': 546, 'text': 'Artico'},
#       {'answer_start': 546, 'text': 'Artico'},
#       {'answer_start': 543, 'text': "l' Artico"},
#       {'answer_start': 543, 'text': "l' Artico"}],
#      'id': '5726241189a1e219009ac2e0',
#      'question': "La crisi petrolifera ha indotto le compagnie petrolifere ad aumentare l' offerta di petrolio in quale area?"},
#     {'answers': [{'answer_start': 640, 'text': 'da cinque a dieci anni'},
#       {'answer_start': 640, 'text': 'da cinque a dieci anni'},
#       {'answer_start': 640, 'text': 'da cinque a dieci anni'},
#       {'answer_start': 640, 'text': 'da cinque a dieci anni'},
#       {'answer_start': 640, 'text': 'da cinque a dieci anni'}],
#      'id': '5726241189a1e219009ac2e1',
#      'question': 'Quanto tempo ci vuole perchè nuove aree abbiano una produzione significativa di petrolio?'}]},
#   {'context': "L' embargo non era uniforme in tutta Europa. Dei nove membri della Comunità Economica Europea (CEE), i Paesi Bassi hanno dovuto affrontare un embargo totale, il Regno Unito e la Francia hanno ricevuto forniture quasi ininterrotte (poichè si sono rifiutati di consentire all' America di utilizzare i loro aerodromi e le armi e forniture embargo sia agli arabi che agli israeliani), mentre gli altri sei hanno dovuto affrontare tagli parziali. Il Regno Unito era tradizionalmente un alleato di Israele, e il governo di Harold Wilson ha sostenuto gli israeliani durante la guerra dei sei giorni. Il suo successore, Ted Heath, ribaltò questa politica nel 1970, chiedendo a Israele di ritirarsi ai suoi confini prima del 1967.",
#    'qas': [{'answers': [{'answer_start': 103, 'text': 'Paesi Bassi'},
#       {'answer_start': 103, 'text': 'Paesi Bassi'},
#       {'answer_start': 103, 'text': 'Paesi Bassi'},
#       {'answer_start': 103, 'text': 'Paesi Bassi'}],
#      'id': '5726487b5951b619008f6edd',
#      'question': 'Quale paese ha dovuto affrontare un embargo totale nella CEE?'},
#     {'answers': [{'answer_start': 275, 'text': 'America'},
#       {'answer_start': 275, 'text': 'America'},
#       {'answer_start': 275, 'text': 'America'},
#       {'answer_start': 275, 'text': 'America'}],
#      'id': '5726487b5951b619008f6ede',
#      'question': "Il Regno Unito e la Francia non hanno avuto interruzioni dell' approvvigionamento petrolifero in quanto non hanno consentito a quale paese di utilizzare il loro aeroporto?"},
#     {'answers': [{'answer_start': 158, 'text': 'Il Regno Unito'},
#       {'answer_start': 158, 'text': 'Il Regno Unito'}],
#      'id': '5726487b5951b619008f6edf',
#      'question': 'Quale paese è un alleato tradizionale di Israele?'},
#     {'answers': [{'answer_start': 492, 'text': 'Israele'},
#       {'answer_start': 492, 'text': 'Israele'},
#       {'answer_start': 368, 'text': 'israeliani'},
#       {'answer_start': 364, 'text': 'gli israeliani'}],
#      'id': '5726487b5951b619008f6ee0',
#      'question': 'Harold WInston ha sostenuto quale paese ha sostenuto durante la sua guerra di sei giorni?'},
#     {'answers': [{'answer_start': 612, 'text': 'Ted Heath'},
#       {'answer_start': 612, 'text': 'Ted Heath'},
#       {'answer_start': 612, 'text': 'Ted Heath'},
#       {'answer_start': 612, 'text': 'Ted Heath'}],
#      'id': '5726487b5951b619008f6ee1',
#      'question': 'Chi voleva che Israele si ritirasse dal suo confine?'}]},
#   {'context': "Nonostante l' embargo sia rimasto relativamente inalterato, il Regno Unito ha tuttavia dovuto affrontare una crisi petrolifera propria: una serie di scioperi dei minatori di carbone e dei lavoratori del settore ferroviario nell' inverno 1973-74 è diventata un fattore importante per il cambiamento di governo. Heath ha chiesto agli inglesi di riscaldare una sola stanza nelle loro case durante l' inverno. Regno Unito, Germania, Italia, Svizzera e Norvegia hanno vietato il volo, la guida e la navigazione domenicale. La Svezia ha razionato benzina e gasolio da riscaldamento. I Paesi Bassi hanno inflitto pene detentive a coloro che hanno utilizzato più della loro razione di elettricità.",
#    'qas': [{'answers': [{'answer_start': 63, 'text': 'Regno Unito'}],
#      'id': '572649d8f1498d1400e8db36',
#      'question': "Quale paese non è gravemente colpito dall' embargo?"},
#     {'answers': [{'answer_start': 136, 'text': 'una serie di scioperi'},
#       {'answer_start': 149,
#        'text': 'scioperi dei minatori di carbone e dei lavoratori del settore ferroviario'},
#       {'answer_start': 136, 'text': 'una serie di scioperi'}],
#      'id': '572649d8f1498d1400e8db37',
#      'question': 'Che cosa ha causato al Regno Unito una crisi petrolifera nel suo paese?'},
#     {'answers': [{'answer_start': 223, 'text': "nell' inverno 1973-74"},
#       {'answer_start': 226, 'text': "l' inverno 1973-74"}],
#      'id': '572649d8f1498d1400e8db38',
#      'question': 'Quando è avvenuta la serie di scioperi?'},
#     {'answers': [{'answer_start': 419, 'text': 'Germania'},
#       {'answer_start': 419, 'text': 'Germania'},
#       {'answer_start': 429, 'text': 'Italia'},
#       {'answer_start': 448, 'text': 'Norvegia'}],
#      'id': '572649d8f1498d1400e8db39',
#      'question': 'Quale paese ha razionato benzina e gas di riscaldamento?'}]},
#   {'context': 'Il controllo dei prezzi ha esacerbato la crisi negli Stati Uniti. Il sistema limitava il prezzo del "vecchio petrolio" (che era già stato scoperto) consentendo la vendita del petrolio appena scoperto ad un prezzo più elevato per incoraggiare gli investimenti. Prevedibilmente, il vecchio petrolio è stato ritirato dal mercato, creando una maggiore scarsità. La regola scoraggiava anche lo sviluppo di energie alternative. La regola era intesa a promuovere la prospezione petrolifera. La questione della scarsità è stata affrontata con il razionamento (come in molti paesi). Gli automobilisti affrontarono lunghe linee nelle stazioni di servizio a partire dall\' estate 1972 e in crescita entro l\' estate 1973.',
#    'qas': [{'answers': [{'answer_start': 3, 'text': 'controllo dei prezzi'},
#       {'answer_start': 3, 'text': 'controllo dei prezzi'},
#       {'answer_start': 3, 'text': 'controllo dei prezzi'},
#       {'answer_start': 3, 'text': 'controllo dei prezzi'},
#       {'answer_start': 3, 'text': 'controllo dei prezzi'}],
#      'id': '57264cac708984140094c1b3',
#      'question': 'Che cosa ha aggravato la crisi petrolifera negli Stati Uniti?'},
#     {'answers': [{'answer_start': 229,
#        'text': 'incoraggiare gli investimenti'},
#       {'answer_start': 229, 'text': 'incoraggiare gli investimenti'},
#       {'answer_start': 229, 'text': 'incoraggiare gli investimenti'},
#       {'answer_start': 229, 'text': 'incoraggiare gli investimenti'},
#       {'answer_start': 66,
#        'text': 'Il sistema limitava il prezzo del "vecchio petrolio"'}],
#      'id': '57264cac708984140094c1b4',
#      'question': 'Perchè il petrolio appena scoperto viene venduto a un prezzo più elevato?'},
#     {'answers': [{'answer_start': 3, 'text': 'controllo dei prezzi'},
#       {'answer_start': 3, 'text': 'controllo dei prezzi'},
#       {'answer_start': 445, 'text': 'promuovere la prospezione petrolifera'},
#       {'answer_start': 66,
#        'text': 'Il sistema limitava il prezzo del "vecchio petrolio"'}],
#      'id': '57264cac708984140094c1b5',
#      'question': 'Perchè il vecchio petrolio è stato ritirato dal mercato?'},
#     {'answers': [{'answer_start': 538, 'text': 'razionamento'},
#       {'answer_start': 538, 'text': 'razionamento'},
#       {'answer_start': 538, 'text': 'razionamento'},
#       {'answer_start': 538, 'text': 'razionamento'},
#       {'answer_start': 538, 'text': 'razionamento'}],
#      'id': '57264cac708984140094c1b7',
#      'question': 'Come è stata gestita la scarsità in molti paesi?'}]},
#   {'context': "Nel 1973, Nixon nominò William E. Simon il primo amministratore dell' Ufficio federale dell' energia, un' organizzazione a breve termine creata per coordinare la risposta all' embargo. Simon assegnava agli Stati la stessa quantità di petrolio domestico per il 1974 che ciascuno aveva consumato nel 1972, che lavorava per gli Stati le cui popolazioni non aumentavano. In altri stati, le linee alle stazioni di benzina erano comuni. L' American Automobile Association ha riferito che nell' ultima settimana di febbraio 1974, il 20% delle stazioni di benzina americane non aveva carburante.",
#    'qas': [{'answers': [{'answer_start': 23, 'text': 'William E. Simon'},
#       {'answer_start': 23, 'text': 'William E. Simon'}],
#      'id': '57264d9edd62a815002e80fe',
#      'question': "Chi è il primo amministratore dell' Ufficio federale dell' energia?"},
#     {'answers': [{'answer_start': 0, 'text': 'Nel 1973'},
#       {'answer_start': 4, 'text': '1973'},
#       {'answer_start': 4, 'text': '1973'},
#       {'answer_start': 4, 'text': '1973'},
#       {'answer_start': 4, 'text': '1973'}],
#      'id': '57264d9edd62a815002e80ff',
#      'question': 'Quando è stato eletto da Nixon?'},
#     {'answers': [{'answer_start': 148,
#        'text': "coordinare la risposta all' embargo"},
#       {'answer_start': 148, 'text': "coordinare la risposta all' embargo"},
#       {'answer_start': 148, 'text': "coordinare la risposta all' embargo"},
#       {'answer_start': 148, 'text': "coordinare la risposta all' embargo"},
#       {'answer_start': 148, 'text': "coordinare la risposta all' embargo"}],
#      'id': '57264d9edd62a815002e8100',
#      'question': 'Perchè è stata creata questa organizzazione a breve termine?'},
#     {'answers': [{'answer_start': 488,
#        'text': 'ultima settimana di febbraio 1974,'},
#       {'answer_start': 526, 'text': '20%'},
#       {'answer_start': 526, 'text': '20'},
#       {'answer_start': 526, 'text': '20%'},
#       {'answer_start': 526, 'text': '20%'}],
#      'id': '57264d9edd62a815002e8101',
#      'question': "Secondo l' AAA, qual è la percentuale delle stazioni di servizio che hanno esaurito la benzina?"}]},
#   {'context': "Per contribuire a ridurre i consumi, nel 1974 è stato imposto un limite massimo nazionale di velocità di 55 mph (circa 88 km/h) attraverso la legge per la conservazione dell' energia delle autostrade di emergenza. Lo sviluppo della Riserva strategica petrolifera è iniziato nel 1975 e nel 1977 è stato creato il Dipartimento dell' energia a livello di gabinetto, seguito dalla legge nazionale sull' energia del 1978. Il 28 novembre 1995, Bill Clinton ha firmato il National Highway Designation Act, che pone fine al limite federale di velocità di 89 km/h, consentendo agli stati di ripristinare il precedente limite massimo di velocità.",
#    'qas': [{'answers': [{'answer_start': 105, 'text': '55 mph'},
#       {'answer_start': 105, 'text': '55 mph'},
#       {'answer_start': 105, 'text': '55 mph'},
#       {'answer_start': 105, 'text': '55 mph'},
#       {'answer_start': 105, 'text': '55 mph'}],
#      'id': '57264efddd62a815002e8134',
#      'question': 'Qual è il limite di velocità impostato per ridurre i consumi?'},
#     {'answers': [{'answer_start': 438, 'text': 'Bill Clinton'},
#       {'answer_start': 438, 'text': 'Bill Clinton'},
#       {'answer_start': 438, 'text': 'Bill Clinton'},
#       {'answer_start': 438, 'text': 'Bill Clinton'},
#       {'answer_start': 438, 'text': 'Bill Clinton'}],
#      'id': '57264efddd62a815002e8136',
#      'question': "Quale presidente ha posto fine alla legge sulla conservazione dell' energia di emergenza?"},
#     {'answers': [{'answer_start': 420, 'text': '28 novembre 1995'},
#       {'answer_start': 420, 'text': '28 novembre 1995'},
#       {'answer_start': 420, 'text': '28 novembre 1995'},
#       {'answer_start': 420, 'text': '28 novembre 1995'},
#       {'answer_start': 420, 'text': '28 novembre 1995'}],
#      'id': '57264efddd62a815002e8137',
#      'question': 'Quando è stato firmato il National Highway Designated Act?'},
#     {'answers': [{'answer_start': 289, 'text': '1977'},
#       {'answer_start': 289, 'text': '1977'},
#       {'answer_start': 289, 'text': '1977'},
#       {'answer_start': 289, 'text': '1977'},
#       {'answer_start': 289, 'text': '1977'}],
#      'id': '57264efddd62a815002e8138',
#      'question': "Quando è stato creato il dipartimento dell' energia a livello di gabinetto?"}]},
#   {'context': "La crisi energetica ha aumentato l' interesse per le energie rinnovabili, il nucleare e i combustibili fossili domestici. Si critica il fatto che le politiche energetiche americane dopo la crisi siano state dominate dal pensiero della mentalità di crisi, che promuovano costose soluzioni rapide e soluzioni a singolo colpo che ignorano le realtà del mercato e della tecnologia. Invece di fornire regole stabili che sostengano la ricerca di base lasciando ampio spazio all' imprenditorialità e all' innovazione, congressi e presidenti hanno ripetutamente sostenuto politiche che promettono soluzioni politicamente opportune, ma le cui prospettive sono dubbie.",
#    'qas': [{'answers': [{'answer_start': 3, 'text': 'crisi energetica'},
#       {'answer_start': 0, 'text': 'La crisi energetica'},
#       {'answer_start': 3, 'text': 'crisi energetica'},
#       {'answer_start': 3, 'text': 'crisi energetica'},
#       {'answer_start': 0, 'text': 'La crisi energetica'}],
#      'id': '572650325951b619008f6fa9',
#      'question': 'Qual è stato il catalizzatore che ha creato maggiore interesse per le risorse rinnovabili?'},
#     {'answers': [{'answer_start': 511, 'text': 'congressi e presidenti'},
#       {'answer_start': 511, 'text': 'congressi e presidenti'},
#       {'answer_start': 511, 'text': 'congressi e presidenti'},
#       {'answer_start': 511, 'text': 'congressi e presidenti'},
#       {'answer_start': 511, 'text': 'congressi e presidenti'}],
#      'id': '572650325951b619008f6fab',
#      'question': 'Chi ha appoggiato politiche che hanno soluzioni valide ma con scarse prospettive?'}]},
#   {'context': 'Nel 2004, documenti declassificati rivelarono che gli Stati Uniti erano così sconvolti dall\' aumento dei prezzi del petrolio e messi in discussione dai paesi sottosviluppati che presero in considerazione un\' azione militare per sequestrare con la forza i giacimenti petroliferi mediorientali alla fine del 1973. Anche se non è stato menzionato alcun piano esplicito, una conversazione tra il Segretario della Difesa americano James Schlesinger e l\' ambasciatore britannico negli Stati Uniti Lord Cromer ha rivelato che Schlesinger gli aveva detto che "non era più ovvio per lui che gli Stati Uniti non poteva usare la forza". Il primo ministro britannico Edward Heath era così preoccupato da questa prospettiva che ha ordinato una stima di intelligence britannica delle intenzioni degli Stati Uniti, che ha concluso l\' America "potrebbe ritenere che non potrebbe tollerare una situazione in cui gli Stati Uniti ed i suoi alleati erano alla mercè di un piccolo gruppo di paesi irragionevoli,,, e che preferirebbero una rapida operazione per sequestrare giacimenti petroliferi in Arabia Saudita e Kuwait, ed eventualmente Abu Dhabi in azione militare". Anche se la risposta sovietica a tale atto probabilmente non avrebbe coinvolto la forza, l\' intelligence ha avvertito "l\' occupazione americana avrebbe avuto bisogno di durare 10 anni come l\' Occidente sviluppato fonti di energia alternative, e avrebbe portato alla\' totale alienazione\' degli arabi e gran parte del resto del Terzo Mondo".',
#    'qas': [{'answers': [{'answer_start': 1327, 'text': '10 anni'},
#       {'answer_start': 1327, 'text': '10 anni'},
#       {'answer_start': 1327, 'text': '10 anni'},
#       {'answer_start': 1327, 'text': '10 anni'}],
#      'id': '57265200708984140094c238',
#      'question': "Quanto tempo dovrà durare l' invasione del Medio Oriente per lo sviluppo delle risorse rinnovabili?"},
#     {'answers': [{'answer_start': 1444,
#        'text': 'arabi e gran parte del resto del Terzo Mondo'},
#       {'answer_start': 1440,
#        'text': 'gli arabi e gran parte del resto del Terzo Mondo'},
#       {'answer_start': 1078, 'text': 'Arabi'},
#       {'answer_start': 1444,
#        'text': 'arabi e gran parte del resto del Terzo Mondo'},
#       {'answer_start': 1440,
#        'text': 'gli arabi e gran parte del resto del Terzo Mondo'}],
#      'id': '57265200708984140094c239',
#      'question': "Chi sarebbe l' occupazione alienarsi?"}]},
#   {'context': 'Anche se mancano i collegamenti storici con il Medio Oriente, il Giappone è stato il paese più dipendente dal petrolio arabo. Il 71% del petrolio importato proveniva dal Medio Oriente nel 1970. Il 7 novembre 1973, il governo saudita e kuwaitiano dichiarò il Giappone un paese "non amichevole" per incoraggiarlo a cambiare la sua politica di non coinvolgimento. A dicembre ha ricevuto un taglio della produzione del 5%, provocando il panico. Il 22 novembre, il Giappone ha rilasciato una dichiarazione "affermando che Israele dovrebbe ritirarsi da tutti i territori del 1967, sostenendo l\' autodeterminazione palestinese e minacciando di riconsiderare la sua politica nei confronti di Israele se Israele si rifiutasse di accettare queste precondizioni". Entro il 25 dicembre, il Giappone era considerato uno stato arabo-friendly.',
#    'qas': [{'answers': [{'answer_start': 65, 'text': 'Giappone'},
#       {'answer_start': 65, 'text': 'Giappone'},
#       {'answer_start': 65, 'text': 'Giappone'},
#       {'answer_start': 65, 'text': 'Giappone'},
#       {'answer_start': 65, 'text': 'Giappone'}],
#      'id': '57265360dd62a815002e819a',
#      'question': 'Quale paese è il più dipendente dal petrolio arabo?'},
#     {'answers': [{'answer_start': 129, 'text': '71%'},
#       {'answer_start': 129, 'text': '71%'},
#       {'answer_start': 129, 'text': '71'},
#       {'answer_start': 129, 'text': '71%'},
#       {'answer_start': 129, 'text': '71%'}],
#      'id': '57265360dd62a815002e819b',
#      'question': 'Quanto petrolio importato proviene dal Medio Oriente?'},
#     {'answers': [{'answer_start': 387,
#        'text': 'taglio della produzione del 5%'}],
#      'id': '57265360dd62a815002e819c',
#      'question': 'Per costringere il Giappone ad essere maggiormente coinvolto nella crisi, cosa ha fatto il governo saudita e kuwaitiano?'},
#     {'answers': [{'answer_start': 444, 'text': '22 novembre'},
#       {'answer_start': 444, 'text': '22 novembre'},
#       {'answer_start': 444, 'text': '22 novembre'},
#       {'answer_start': 444, 'text': '22 novembre'},
#       {'answer_start': 444, 'text': '22 novembre'}],
#      'id': '57265360dd62a815002e819d',
#      'question': 'Quando il Giappone ha rilasciato una dichiarazione per dire agli israeliani di ritirarsi dalla Palestina?'}]},
#   {'context': 'L\' invasione dell\' URSS dell\' Afghanistan è stato solo un segno di insicurezza nella regione, caratterizzato anche da un aumento delle vendite di armi americane, tecnologia e presenza militare. L\' Arabia Saudita e l\' Iran sono diventati sempre più dipendenti dalle garanzie di sicurezza americane per gestire le minacce sia esterne che interne, compresa l\' aumento della concorrenza militare tra di loro a causa dell\' aumento dei proventi petroliferi. Entrambi gli Stati competevano per la preminenza nel Golfo Persico e utilizzavano maggiori entrate per finanziare militari in espansione. Nel 1979, gli acquisti di armi saudite dagli Stati Uniti superavano il quintuplo di Israele. Un altro motivo per l\' acquisto su larga scala di armi dagli Stati Uniti da parte dell\' Arabia Saudita fu il fallimento dello scià nel gennaio 1979 a mantenere il controllo dell\' Iran, una nazione musulmana non araba ma in gran parte sciita, che cadde sotto l\' Ayatollah Ruhollah Khomeini, sotto il governo teocratico islamista sulla scia della Rivoluzione iraniana del 1979. L\' Arabia Saudita, invece, è una nazione araba, in gran parte sunnita musulmana, guidata da una monarchia quasi assolutista. Sulla scia della rivoluzione iraniana i sauditi furono costretti ad affrontare la prospettiva della destabilizzazione interna attraverso il radicalismo dell\' islamismo, una realtà che si sarebbe rapidamente rivelata nella presa della Grande Moschea in Mecca da parte degli estremisti wahhabiti nel novembre 1979 e nella rivolta sciita nella ricca regione petrolifera di Al-Hasa in Arabia Saudita nel dicembre dello stesso anno. Nel novembre 2010, Wikileaks ha trapelato cavi diplomatici confidenziali riguardanti gli Stati Uniti e i loro alleati, rivelando che il compianto Re Saudita Abdullah ha esortato gli Stati Uniti ad attaccare l\' Iran per distruggere il suo potenziale programma di armi nucleari, descrivendo l\' Iran come "un serpente la cui testa dovrebbe essere tagliata fuori senza alcuna procrastinazione".',
#    'qas': [{'answers': [{'answer_start': 3, 'text': "invasione dell' URSS"},
#       {'answer_start': 30, 'text': 'Afghanistan'},
#       {'answer_start': 19, 'text': 'URSS'},
#       {'answer_start': 30, 'text': 'Afghanistan'}],
#      'id': '57265526708984140094c2bd',
#      'question': "L' invasione di quale paese mostra l' insicurezza del Medio Oriente?"},
#     {'answers': [{'answer_start': 197, 'text': 'Arabia Saudita'},
#       {'answer_start': 197, 'text': 'Arabia Saudita'},
#       {'answer_start': 197, 'text': 'Arabia Saudita'},
#       {'answer_start': 197, 'text': 'Arabia Saudita'},
#       {'answer_start': 197, 'text': 'Arabia Saudita'}],
#      'id': '57265526708984140094c2bf',
#      'question': 'Quale paese di acquisto di armi dagli Stati Uniti è diventato 5 volte più di Israele?'},
#     {'answers': [{'answer_start': 818, 'text': 'gennaio 1979'},
#       {'answer_start': 594, 'text': '1979'},
#       {'answer_start': 594, 'text': '1979'},
#       {'answer_start': 594, 'text': '1979'},
#       {'answer_start': 818, 'text': 'gennaio 1979'}],
#      'id': '57265526708984140094c2c0',
#      'question': 'Quando è crollato il regno dello Shah?'},
#     {'answers': [{'answer_start': 1482, 'text': 'novembre 1979'},
#       {'answer_start': 1482, 'text': 'novembre 1979'},
#       {'answer_start': 1482, 'text': 'novembre 1979'},
#       {'answer_start': 1482, 'text': 'novembre 1979'},
#       {'answer_start': 1482, 'text': 'novembre 1979'}],
#      'id': '57265526708984140094c2c1',
#      'question': 'Quando ha preso la Grande Moschea della Mecca?'}]},
#   {'context': "La crisi ha ridotto la domanda di automobili di grandi dimensioni. Importazioni giapponesi, principalmente la Toyota Corona, la Toyota Corolla, il Datsun B210, il Datsun 510, la Honda Civic, il Mitsubishi Galant (un' importazione vincolata da Chrysler venduto come il Dodge Colt), la Subaru DL, e più tardi l' Honda Accord tutti avevano quattro motori a quattro cilindri che erano più efficienti rispetto al carburante tipico americano V8 e sei motori a sei cilindri. Le importazioni giapponesi sono diventate leader del mercato di massa grazie alla costruzione unibody e alla trazione anteriore, che sono diventate norme de facto.",
#    'qas': [{'answers': [{'answer_start': 67,
#        'text': 'Importazioni giapponesi'},
#       {'answer_start': 80, 'text': 'giappone'}],
#      'id': '5726581fdd62a815002e823b',
#      'question': 'Quali auto del paese sono diventate più ricercate perchè più efficienti dal punto di vista dei consumi?'},
#     {'answers': [{'answer_start': 80, 'text': 'giappone'},
#       {'answer_start': 80, 'text': 'giappone'}],
#      'id': '5726581fdd62a815002e823d',
#      'question': 'Quali importazioni di questo paese sono diventate di fatto leader del mercato di massa?'}]},
#   {'context': "Alcuni acquirenti lamentavano le piccole dimensioni dei primi compatti giapponesi, e sia Toyota e Nissan (allora noto come Datsun) ha introdotto le automobili più grandi come la Toyota Corona Mark II, la Toyota Cressida, la Mazda 616 e Datsun 810, che ha aggiunto spazio passeggeri e servizi come aria condizionata, servosterzo, radio AM-FM, e anche gli alzacristalli elettrici e chiusura centralizzata senza aumentare il prezzo del veicolo. Un decennio dopo la crisi petrolifera del 1973, Honda, Toyota e Nissan, colpite dalle restrizioni volontarie all' esportazione del 1981, aprono gli impianti di assemblaggio statunitensi e istituiscono le loro divisioni di lusso (Acura, Lexus e Infiniti, rispettivamente) per distinguersi dai loro marchi di massa.",
#    'qas': [{'answers': [{'answer_start': 573, 'text': '1981'},
#       {'answer_start': 573, 'text': '1981'},
#       {'answer_start': 442,
#        'text': 'Un decennio dopo la crisi petrolifera del 1973'},
#       {'answer_start': 573, 'text': '1981'}],
#      'id': '572659535951b619008f703f',
#      'question': 'Quando Honda, Toyota e Nissan hanno aperto impianti di assemblaggio negli Stati Uniti?'},
#     {'answers': [{'answer_start': 178, 'text': 'Toyota Corona Mark II'},
#       {'answer_start': 185, 'text': 'Corona Mark II'},
#       {'answer_start': 178, 'text': 'Toyota Corona Mark II'},
#       {'answer_start': 185, 'text': 'Corona Mark II'}],
#      'id': '572659535951b619008f7040',
#      'question': "Nome di un' auto più grande che Toyota ha creato come acquirenti lamentato le piccole dimensioni compatte?"}]},
#   {'context': "Furono introdotti autocarri compatti, come la Toyota Hilux e il Datsun Truck, seguiti dal camion Mazda (venduto come il Ford Courier), e l' Isuzu costruito Chevrolet LUV. Mitsubishi rebranded il suo Forte come Dodge D-50 pochi anni dopo la crisi petrolifera. Mazda, Mitsubishi e Isuzu avevano partnership congiunte rispettivamente con Ford, Chrysler e GM. In seguito i produttori americani introdussero le loro sostituzioni nazionali (Ford Ranger, Dodge Dakota e la Chevrolet S10/GMC S-15), ponendo fine alla loro politica di importazione vincolata.",
#    'qas': [{'answers': [{'answer_start': 46, 'text': 'Toyota Hilux'},
#       {'answer_start': 53, 'text': 'Hilux'},
#       {'answer_start': 53, 'text': 'Hilux'},
#       {'answer_start': 46, 'text': 'Toyota Hilux'},
#       {'answer_start': 53, 'text': 'Hilux'}],
#      'id': '57265a58dd62a815002e8270',
#      'question': 'Denominare un tipo di camion compatti Toyota?'},
#     {'answers': [{'answer_start': 210, 'text': 'Dodge D-50'},
#       {'answer_start': 210, 'text': 'Dodge D-50'},
#       {'answer_start': 210, 'text': 'Dodge D-50'},
#       {'answer_start': 210, 'text': 'Dodge D-50'},
#       {'answer_start': 210, 'text': 'Dodge D-50'}],
#      'id': '57265a58dd62a815002e8271',
#      'question': 'Che cosa ha fatto Mitsubishi ribattezzato il suo Forte?'},
#     {'answers': [{'answer_start': 335, 'text': 'Ford, Chrysler e GM'},
#       {'answer_start': 335, 'text': 'Ford, Chrysler e GM'},
#       {'answer_start': 120, 'text': 'Ford'},
#       {'answer_start': 335, 'text': 'Ford, Chrysler e GM'}],
#      'id': '57265a58dd62a815002e8272',
#      'question': 'Mazda, Mitsubishi e Isuzu hanno aderito alla partnership con quale casa automobilistica americana?'},
#     {'answers': [{'answer_start': 526, 'text': 'importazione vincolata'},
#       {'answer_start': 526, 'text': 'importazione vincolata'},
#       {'answer_start': 526, 'text': 'importazione vincolata'},
#       {'answer_start': 526, 'text': 'importazione vincolata'}],
#      'id': '57265a58dd62a815002e8273',
#      'question': 'Quando le case automobilistiche americane si sono schierate con le loro auto sostitutive nazionali, quale politica si è conclusa?'}]},
#   {'context': "L' aumento delle importazioni di automobili nel Nord America ha costretto General Motors, Ford e Chrysler a introdurre modelli più piccoli e a basso consumo di carburante per le vendite nazionali. La Dodge Omni / Plymouth Horizon di Chrysler, la Ford Fiesta e la Chevrolet Chevette avevano tutti motori a quattro cilindri e spazio per almeno quattro passeggeri alla fine degli anni Settanta. Nel 1985, il veicolo americano medio si è spostato di 17,4 miglia per gallone, contro i 13,5 del 1970. I miglioramenti sono rimasti invariati anche se il prezzo di un barile di petrolio è rimasto costante a 12 dollari tra il 1974 e il 1979. Vendita di grandi berline per la maggior parte delle marche (tranne i prodotti Chrysler) recuperato entro due anni modello della crisi 1973. La Cadillac DeVille e Fleetwood, Buick Electra, Oldsmobile 98, Lincoln Continental, Mercury Marquis, e varie altre berline di lusso orientato di nuovo popolare a metà degli anni Settanta. Gli unici modelli full-size che non hanno recuperato erano modelli a prezzo inferiore come la Chevrolet Bel Air e la Ford Galaxie 500. Modelli leggermente più piccoli, di medie dimensioni come Oldsmobile Cutlass, Chevrolet Monte Carlo, Ford Thunderbird e vari altri modelli venduti bene.",
#    'qas': [{'answers': [{'answer_start': 335,
#        'text': 'almeno quattro passeggeri'},
#       {'answer_start': 305, 'text': 'quattro'},
#       {'answer_start': 335, 'text': 'almeno quattro passeggeri'},
#       {'answer_start': 335, 'text': 'almeno quattro'},
#       {'answer_start': 305, 'text': 'quattro'}],
#      'id': '57265bdfdd62a815002e829f',
#      'question': 'Quanti passeggeri può ospitare la Ford Fiesta?'},
#     {'answers': [{'answer_start': 396, 'text': '1985'},
#       {'answer_start': 396, 'text': '1985'},
#       {'answer_start': 396, 'text': '1985'},
#       {'answer_start': 396, 'text': '1985'},
#       {'answer_start': 396, 'text': '1985'}],
#      'id': '57265bdfdd62a815002e82a0',
#      'question': "Da quale anno l' auto americana mpg ha iniziato a migliorare?"},
#     {'answers': [{'answer_start': 837, 'text': 'Lincoln Continental,'},
#       {'answer_start': 777, 'text': 'Cadillac DeVille'},
#       {'answer_start': 777, 'text': 'Cadillac DeVille'},
#       {'answer_start': 777, 'text': 'Cadillac DeVille'}],
#      'id': '57265bdfdd62a815002e82a1',
#      'question': 'Nome di un modello di lusso che è diventato popolare a metà degli anni Settanta?'}]},
#   {'context': 'Gli standard di sicurezza federali, come il NHTSA Federal Motor Vehicle Safety Standard 215 (relativo ai paraurti di sicurezza), e le compatte come il Mustang I del 1974 sono stati un preludio alla revisione "downsize" delle categorie di veicoli DOT. Nel 1977, le automobili di GM a grandezza naturale riflettevano la crisi. Nel 1979, praticamente tutte le auto "full-size" americane si erano ritirate, con motori più piccoli e dimensioni esterne più piccole. Chrysler ha terminato la produzione delle loro berline di lusso full-size alla fine dell\' anno 1981, passando invece ad una linea completa di trazione anteriore per 1982 (tranne le berline M-body Dodge Diplomat/Plymouth Gran Fury e Chrysler New Yorker Fifth Avenue).',
#    'qas': [{'answers': [{'answer_start': 329, 'text': '1979'},
#       {'answer_start': 329, 'text': '1979'},
#       {'answer_start': 329, 'text': '1979'},
#       {'answer_start': 329, 'text': '1979'},
#       {'answer_start': 329, 'text': '1979'}],
#      'id': '57265ceddd62a815002e82b8',
#      'question': 'Da quale anno le auto americane di dimensioni piene si sono ridotte per essere più piccole?'},
#     {'answers': [{'answer_start': 555, 'text': '1981'},
#       {'answer_start': 555, 'text': '1981'},
#       {'answer_start': 555, 'text': '1981'},
#       {'answer_start': 555, 'text': '1981'},
#       {'answer_start': 555, 'text': '1981'}],
#      'id': '57265ceddd62a815002e82b9',
#      'question': 'Da che anno Chrysler ha chiuso il suo modello di lusso di dimensioni complete?'},
#     {'answers': [{'answer_start': 151, 'text': 'Mustang I'},
#       {'answer_start': 151, 'text': 'Mustang I'},
#       {'answer_start': 151, 'text': 'Mustang I'}],
#      'id': '57265ceddd62a815002e82ba',
#      'question': 'Quale vettura mostra la revisione delle categorie effettuata dal DOT?'}]},
#   {'context': 'L\' OPEC perse presto la sua posizione preminente e nel 1981 la sua produzione fu superata da quella di altri paesi. Inoltre, le proprie nazioni membri erano divise. L\' Arabia Saudita, cercando di recuperare quote di mercato, ha aumentato la produzione, abbassato i prezzi, ridotto o eliminato i profitti per i produttori ad alto costo. Il prezzo mondiale, che aveva raggiunto il picco massimo durante la crisi energetica del 1979 a quasi 40 dollari al barile, è sceso negli anni\' 80 a meno di 10 dollari al barile. Al netto dell\' inflazione, il petrolio è sceso brevemente ai livelli precedenti al 1973. Questo prezzo di "vendita" è stato un vantaggio per le nazioni importatrici di petrolio, sia in via di sviluppo che di sviluppo.',
#    'qas': [{'answers': [{'answer_start': 55, 'text': '1981'},
#       {'answer_start': 55, 'text': '1981'},
#       {'answer_start': 55, 'text': '1981'},
#       {'answer_start': 55, 'text': '1981'},
#       {'answer_start': 55, 'text': '1981'}],
#      'id': '57265e11708984140094c3bb',
#      'question': 'Quando è stata superata la produzione di olio OPEC?'},
#     {'answers': [{'answer_start': 468, 'text': "negli anni' 80"}],
#      'id': '57265e11708984140094c3bc',
#      'question': 'Quale anno il prezzo del petrolio è sceso a 10 dollari al barile?'},
#     {'answers': [{'answer_start': 196, 'text': 'recuperare quote di mercato'},
#       {'answer_start': 196, 'text': 'recuperare quote di mercato'},
#       {'answer_start': 196, 'text': 'recuperare quote di mercato'},
#       {'answer_start': 196, 'text': 'recuperare quote di mercato'}],
#      'id': '57265e11708984140094c3bd',
#      'question': "Perchè l' Arabia Saudita ha cercato di aumentare la produzione e ridurre i profitti per i produttori ad alto costo?"}]}],
#  'title': 'Crisi energetica (1973)'}
